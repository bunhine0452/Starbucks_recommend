# %%
from fastapi import FastAPI, HTTPException
from pydantic import BaseModel
import pandas as pd
import numpy as np
import torch
from transformers import BertModel, BertTokenizer
from konlpy.tag import Okt
import ast
from sklearn.metrics.pairwise import cosine_similarity
import nest_asyncio
import uvicorn
import time
import hashlib  # 입력 해시 생성용
import os
import json

# Jupyter Notebook에서 asyncio 문제 해결
nest_asyncio.apply()

app = FastAPI(
    title='스타벅스추천 모델',
    description='키워드 맞춤 검색기 koBERT 사용',
    version='0.0.1',
    servers=[
        {
            #'url': 'https://55cd-1-221-198-246.ngrok-free.app',
            'url': '',
            'description': 'Everything that you want to know is here.'
        }
    ]
)


# MPS 장치 사용 여부 확인
device = torch.device('mps') if torch.backends.mps.is_available() else torch.device('cpu')
print(f"Using device: {device}")

# KoBERT 모델과 토크나이저 로드 및 초기화
model_name = 'monologg/kobert'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)
model.to(device)
print("KoBERT 모델과 토크나이저 로드 완료")

# 단어 임베딩을 캐싱하기 위한 딕셔너리
embedding_cache = {}

# 캐시 디렉토리 설정
CACHE_DIR = './cache'
if not os.path.exists(CACHE_DIR):
    os.makedirs(CACHE_DIR)

def get_embeddings_with_cache(words):
    embeddings = []
    words_to_process = []
    for word in words:
        if word in embedding_cache:
            embeddings.append(embedding_cache[word])
        else:
            words_to_process.append(word)
    
    if words_to_process:
        inputs = tokenizer(words_to_process, return_tensors='pt', padding=True, truncation=True, max_length=512)
        inputs = {key: value.to(device) for key, value in inputs.items()}
        with torch.no_grad():
            outputs = model(**inputs)
        new_embeddings = outputs.last_hidden_state.mean(dim=1).cpu().numpy()
        for word, embedding in zip(words_to_process, new_embeddings):
            embedding_cache[word] = embedding
            embeddings.append(embedding)
    
    return np.array(embeddings)

# 불용어 리스트
stopwords = ['스타', '벅스', '스타벅스', '스벅', '매장', '카페']

# 불용어 제거 함수
def remove_stopwords(nouns, stopwords):
    return [noun for noun in nouns if noun not in stopwords]

# 사용자 입력 명사 추출 함수 정의 및 불용어 제거 적용
def extract_nouns(user_input):
    okt = Okt()
    nouns = okt.nouns(user_input)
    filtered_nouns = remove_stopwords(nouns, stopwords)
    return filtered_nouns

# 빈 데이터 필터링 함수
def filter_data(data, user_input):
    filtered_data = data.copy()
    # 매장 타입 관련 필터링
    if '리저브' in user_input or 'Reserve' in user_input or 'reserve' in user_input:
        filtered_data = filtered_data[filtered_data['storeType'] == '리저브']
    if '일반' in user_input or 'Standard' in user_input or 'standard' in user_input:
        filtered_data = filtered_data[filtered_data['storeType'] == '일반']
    if '드라이브 스루' in user_input or '드라이브스루' in user_input or 'drivethrough' in user_input:
        filtered_data = filtered_data[filtered_data['storeType'] == '드라이브스루']

    # 위치 관련 필터링
    if '서울시' in user_input or '서울특별시' in user_input or '수도' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('서울특별시')] 
    if '부산' in user_input or '부산시' in user_input or '부산광역시' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('부산')]
    if '대구' in user_input or '대구시' in user_input or '대구광역시' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('대구')]
    if '인천' in user_input or '인천광역시' in user_input or '인천시' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('인천')]
    if '광주' in user_input or '광주광역시' in user_input or 'gwangju' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('광주광역시')]
    if '대전' in user_input or '대전시' in user_input or '대전광역시' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('대전')]
    if '울산' in user_input or '울산시' in user_input or '울산광역시' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('울산')]
    if '세종' in user_input or '세종특별시' in user_input or 'sejong' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('세종특별자치시')]
    if '경기' in user_input or '경기도' in user_input or '수도권' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('경기')]
    if '강원' in user_input or '강원도' in user_input or 'gangwon' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('강원')]
    if '충북' in user_input or '충청북도' in user_input or 'chungbuk' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('충청북도')]
    if '충남' in user_input or '충청남도' in user_input or 'chungnam' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('충청남도')]
    if '전북' in user_input or '전라북도' in user_input or 'jeonbuk' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('전라북도')]
    if '전남' in user_input or '전라남도' in user_input or 'jeonnam' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('전라남도')]
    if '경북' in user_input or '경상북도' in user_input or 'gyeongbuk' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('경상북도')]
    if '경남' in user_input or '경상남도' in user_input or 'gyeongnam' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('경상남도')]
    if '제주' in user_input or 'Jeju' in user_input or 'jeju' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('제주')]
    
    # 대한민국 시 목록으로 필터링
    
    # 경기도
    if '수원시' in user_input or '수원' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('수원시')]
    if '용인시' in user_input or '용인' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('용인시')]
    if '고양시' in user_input or '고양' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('고양시')]
    if '화성시' in user_input or '화성' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('화성시')]
    if '성남시' in user_input or '성남' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('성남시')]
    if '부천시' in user_input or '부천' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('부천시')]
    if '남양주시' in user_input or '남양주' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('남양주시')]
    if '안산시' in user_input or '안산' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('안산시')]
    if '평택시' in user_input or '평택' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('평택시')]
    if '안양시' in user_input or '안양' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('안양시')]
    if '시흥시' in user_input or '시흥' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('시흥시')]
    if '파주시' in user_input or '파주' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('파주시')]
    if '김포시' in user_input or '김포' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('김포시')]
    if '의정부시' in user_input or '의정부' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('의정부시')]
    if '광주시' in user_input or '경기 광주' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('경기도 광주')]
    if '하남시' in user_input or '하남' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('하남시')]
    if '광명시' in user_input or '광명' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('광명시')]
    if '군포시' in user_input or '군포' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('군포시')]
    if '양주시' in user_input or '양주' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('양주시')]
    if '오산시' in user_input or '오산' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('오산시')]
    if '이천시' in user_input or '이천' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('이천시')]
    if '안성시' in user_input or '안성' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('안성시')]
    if '구리시' in user_input or '구리' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('구리시')]
    if '의왕시' in user_input or '의왕' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('의왕시')]
    if '포천시' in user_input or '포천' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('포천시')]

    
    # 강원특별자치도
    if '춘천시' in user_input or '춘천' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('춘천시')]
    if '원주시' in user_input or '원주' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('원주시')]
    if '강릉시' in user_input or '강릉' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('강릉시')]
    if '동해시' in user_input or '동해' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('동해시')]
    if '속초시' in user_input or '속초' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('속초시')]
    if '삼척시' in user_input or '삼척' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('삼척시')]
    
    # 전라남도
    if '목포시' in user_input or '목포' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('목포시')]
    if '여수시' in user_input or '여수' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('여수시')]
    if '순천시' in user_input or '순천' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('순천시')]
    if '나주시' in user_input or '나주' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('나주시')]
    if '광양시' in user_input or '광양' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('광양시')]
    # 전라북도
    if '전주시' in user_input or '전주' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('전주시')]
    if '군산시' in user_input or '군산' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('군산시')]
    if '익산시' in user_input or '익산' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('익산시')]
    if '정읍시' in user_input or '정읍' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('정읍시')]
    if '남원시' in user_input or '남원' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('남원시')]
    if '김제시' in user_input or '김제' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('김제시')]

    # 경상북도
    if '포항시' in user_input or '포항' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('포항시')]
    if '경주시' in user_input or '경주' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('경주시')]
    if '김천시' in user_input or '김천' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('김천시')]
    if '안동시' in user_input or '안동' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('안동시')]
    if '구미시' in user_input or '구미' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('구미시')]
    if '영주시' in user_input or '영주' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('영주시')]
    if '영천시' in user_input or '영천' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('영천시')]
    if '상주시' in user_input or '상주' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('상주시')]
    if '문경시' in user_input or '문경' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('문경시')]
    if '경산시' in user_input or '경산' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('경산시')]

    # 경상남도
    if '창원시' in user_input or '창원' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('창원시')]
    if '진주시' in user_input or '진주' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('진주시')]
    if '통영시' in user_input or '통영' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('통영시')]
    if '사천시' in user_input or '사천' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('사천시')]
    if '김해시' in user_input or '김해' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('김해시')]
    if '밀양시' in user_input or '밀양' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('밀양시')]
    if '거제시' in user_input or '거제' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('거제시')]
    if '양산시' in user_input or '양산' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('양산시')]

    # 충청남도 
    if '천안시' in user_input or '천안' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('천안시')]
    if '공주시' in user_input or '공주' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('공주시')]
    if '보령시' in user_input or '보령' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('보령시')]
    if '아산시' in user_input or '아산' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('아산시')]
    if '서산시' in user_input or '서산' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('서산시')]
    if '논산시' in user_input or '논산' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('논산시')]
    if '계룡시' in user_input or '계룡' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('계룡시')]
    if '당진시' in user_input or '당진' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('당진시')]
    
    # 충청북도
    if '청주시' in user_input or '청주' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('청주시')]
    if '충주시' in user_input or '충주' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('충주시')]
    if '제천시' in user_input or '제천' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('제천시')]

    
    # 서울시 지하철 역 입력시 구로 반환
    # 강남구
    if '삼성역' in user_input or '선릉역' in user_input or '역삼역' in user_input or '강남역' in user_input or '압구정역' in user_input or '신사역' in user_input or '매봉역' in user_input or '도곡역' in user_input or '대치역' in user_input or '학여울역' in user_input or '대청역' in user_input or '일원역' in user_input or '수서역' in user_input or '강남구청역' in user_input or '학동역' in user_input or '논현역' in user_input or '신논현역' in user_input or '언주역' in user_input or '선정릉역' in user_input or '삼성중앙역' in user_input or '봉은사역' in user_input or '압구정로데오역' in user_input or '한티역' in user_input or '구릉역' in user_input or '개포동역' in user_input or '대모산역' in user_input or '청담역' in user_input or '강남구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('강남구')]

    # 강동구
    if '천호역' in user_input or '강동역' in user_input or '길동역' in user_input or '굽은다리역' in user_input or '명일역' in user_input or '고덕역' in user_input or '상일동역' in user_input or '강일역' in user_input or '둔촌동역' in user_input or '암사역' in user_input or '강동구청역' in user_input or '둔촌오륜역' in user_input or '중앙보훈병원역' in user_input or '강동구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('강동구')]

    # 강북구
    if '미아사거리역' in user_input or '미아역' in user_input or '수유역' in user_input or '솔샘역' in user_input or '삼양사거리역' in user_input or '삼양역' in user_input or '화계역' in user_input or '가오리역' in user_input or '4.19민주묘지역' in user_input or '솔밭공원역' in user_input or '북한산우이역' in user_input or '강북구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('강북구')]

    # 강서구
    if '까치산역' in user_input or '방화역' in user_input or '개화산역' in user_input or '김포공항역' in user_input or '송정역' in user_input or '마곡역' in user_input or '발산역' in user_input or '우장산역' in user_input or '화곡역' in user_input or '공항시장역' in user_input or '신방화역' in user_input or '마곡나루역' in user_input or '양천향교역' in user_input or '가양역' in user_input or '증미역' in user_input or '등촌역' in user_input or '염창역' in user_input or '강서구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('강서구')]

    # 관악구
    if '낙성대역' in user_input or '서울대입구역' in user_input or '봉천역' in user_input or '신림역' in user_input or '당곡역' in user_input or '서원역' in user_input or '서울대벤처타운역' in user_input or '관악산역' in user_input or '관악구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('관악구')]

    # 광진구
    if '건대입구역' in user_input or '구의역' in user_input or '강변역' in user_input or '군자역' in user_input or '아차산역' in user_input or '광나루역' in user_input or '중곡역' in user_input or '어린이대공원역' in user_input or '뚝섬유원지역' in user_input or '광진구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('광진구')]
    # 구로구
    if '구로역' in user_input or '구일역' in user_input or '개봉역' in user_input or '오류동역' in user_input or '온수역' in user_input or '신도림역' in user_input or '구로디지털단지역' in user_input or '대림역' in user_input or '도림천역' in user_input or '남구로역' in user_input or '천왕역' in user_input or '구로구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('구로구')]

    # 금천구
    if '금천구청역' in user_input or '독산역' in user_input or '가산디지털단지역' in user_input or '금천구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('금천구')]
    
    # 노원구
    if '석계역' in user_input or '광운대역' in user_input or '월계역' in user_input or '노원역' in user_input or '상계역' in user_input or '당고개역' in user_input or '화랑대역' in user_input or '태릉입구역' in user_input or '수락산역' in user_input or '마들역' in user_input or '중계역' in user_input or '하계역' in user_input or '공릉역' in user_input or '노원구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('노원구')]

    # 도봉구
    if '녹천역' in user_input or '창동역' in user_input or '방학역' in user_input or '도봉역' in user_input or '도봉산역' in user_input or '쌍문역' in user_input or '도봉구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('도봉구')]

    # 동대문구
    if '신설동역' in user_input or '제기동역' in user_input or '청량리역' in user_input or '회기역' in user_input or '외대앞역' in user_input or '신이문역' in user_input or '용두역' in user_input or '답십리역' in user_input or '장한평역' in user_input or '동대문구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('동대문구')]
    
    # 동작구
    if '노량진역' in user_input or '사당역' in user_input or '신대방역' in user_input or '이수역' in user_input or '총신대입구역' in user_input or '동작역' in user_input or '남성역' in user_input or '숭실대입구역' in user_input or '상도역' in user_input or '장승배기역' in user_input or '신대방삼거리역' in user_input or '노들역' in user_input or '흑석역' in user_input or '보라매공원역' in user_input or '보라매병원역' in user_input or '동작구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('동작구')]

    # 마포구
    if '합정역' in user_input or '홍대입구역' in user_input or '신촌역' in user_input or '이대역' in user_input or '아현역' in user_input or '마포역' in user_input or '공덕역' in user_input or '애오개역' in user_input or '대흥역' in user_input or '광흥창역' in user_input or '상수역' in user_input or '망원역' in user_input or '마포구청역' in user_input or '월드컵경기장역' in user_input or '디지털미디어시티역' in user_input or '서강대역' in user_input or '마포구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('마포구')]

    # 서대문구
    if '충정로역' in user_input or '홍제역' in user_input or '무악재역' in user_input or '서대문역' in user_input or '가좌역' in user_input or '서대문구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('서대문구')]


    # 서초구
    if '교대역' in user_input or '서초역' in user_input or '방배역' in user_input or '잠원역' in user_input or '고속터미널역' in user_input or '남부터미널역' in user_input or '양재역' in user_input or '남태령역' in user_input or '반포역' in user_input or '내방역' in user_input or '구반포역' in user_input or '신반포역' in user_input or '사평역' in user_input or '양재시민의숲역' in user_input or '청계산입구역' in user_input or '서초구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('서초구')]


    # 성동구
    if '상왕십리역' in user_input or '왕십리역' in user_input or '한양대역' in user_input or '뚝섬역' in user_input or '성수역' in user_input or '용답역' in user_input or '신답역' in user_input or '금호역' in user_input or '옥수역' in user_input or '신금호역' in user_input or '행당역' in user_input or '마장역' in user_input or '응봉역' in user_input or '서울숲역' in user_input or '성동구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('성동구')]


    # 성북구
    if '한성대입구역' in user_input or '성신여대입구역' in user_input or '길음역' in user_input or '돌곶이역' in user_input or '상월곡역' in user_input or '월곡역' in user_input or '고려대역' in user_input or '안암역' in user_input or '보문역' in user_input or '북한산보국문역' in user_input or '정릉역' in user_input or '성북구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('성북구')]


    # 송파구
    if '잠실나루역' in user_input or '잠실역' in user_input or '잠실새내역' in user_input or '종합운동장역' in user_input or '가락시장역' in user_input or '경찰병원역' in user_input or '오금역' in user_input or '올림픽공원역' in user_input or '방이역' in user_input or '개롱역' in user_input or '거여역' in user_input or '마천역' in user_input or '몽촌토성역' in user_input or '석촌역' in user_input or '송파역' in user_input or '문정역' in user_input or '장지역' in user_input or '복정역' in user_input or '삼전역' in user_input or '석촌고분역' in user_input or '송파나루역' in user_input or '한성백제역' in user_input or '송파구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('송파구')]

    # 양천구
    if '양천구청역' in user_input or '신정네거리역' in user_input or '신정역' in user_input or '목동역' in user_input or '오목교역' in user_input or '신목동역' in user_input or '양천구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('양천구')]

    # 영등포구
    if '영등포역' in user_input or '신길역' in user_input or '대방역' in user_input or '문래역' in user_input or '영등포구청역' in user_input or '당산역' in user_input or '양평역' in user_input or '영등포시장역' in user_input or '여의도역' in user_input or '여의나루역' in user_input or '보라매역' in user_input or '신풍역' in user_input or '선유도역' in user_input or '국회의사당역' in user_input or '샛강역' in user_input or '서울지방병무청역' in user_input or '영등포구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('영등포구')]


    # 용산구
    if '용산역' in user_input or '남영역' in user_input or '서울역' in user_input or '이촌역' in user_input or '신용산역' in user_input or '삼각지역' in user_input or '숙대입구역' in user_input or '한강진역' in user_input or '이태원f역' in user_input or '녹사평역' in user_input or '효창공원앞역' in user_input or '서빙고역' in user_input or '한남역' in user_input or '용산구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('용산구')]

    # 은평구
    if '구파발역' in user_input or '연신내역' in user_input or '불광역' in user_input or '녹번역' in user_input or '디지털미디어시티역' in user_input or '증산역' in user_input or '새절역' in user_input or '응암역' in user_input or '구산역' in user_input or '독바위역' in user_input or '역촌역' in user_input or '응암역' in user_input or '수색역' in user_input or '은평구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('은평구')]


    # 종로구
    if '종각역' in user_input or '종로3가역' in user_input or '종로5가역' in user_input or '동대문역' in user_input or '동묘앞역' in user_input or '독립문역' in user_input or '경복궁역' in user_input or '안국역' in user_input or '혜화역' in user_input or '광화문역' in user_input or '창신역' in user_input or '종로구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('종로구')]


    # 중구
    if '서울역' in user_input or '시청역' in user_input or '을지로입구역' in user_input or '을지로3가역' in user_input or '을지로4가역' in user_input or '동대문역사문화공원역' in user_input or '신당역' in user_input or '충무로역' in user_input or '동대입구역' in user_input or '약수역' in user_input or '회현역' in user_input or '명동역' in user_input or '청구역' in user_input or '버티고개역' in user_input or '중구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('중구')]

    # 중랑구
    if '신내역' in user_input or '봉화산역' in user_input or '먹골역' in user_input or '중화역' in user_input or '상봉역' in user_input or '면목역' in user_input or '사가정역' in user_input or '용마산역' in user_input or '중랑역' in user_input or '망우역' in user_input or '양원역' in user_input or '중랑구' in user_input:
        filtered_data = filtered_data[filtered_data['storeAddress'].str.contains('중랑구')]



    # 시설 관련 필터링
    if '주차공간 있는' in user_input or '주차가능' in user_input or '주차' in user_input or '주차 가능' in user_input:
        filtered_data = filtered_data[filtered_data['parking'] == True]
    if '주차공간이없는' in user_input or '주차가불가' in user_input or '차대는곳 없는' in user_input or '주차 불가능' in user_input:
        filtered_data = filtered_data[filtered_data['parking'] == False]
    if '주차불가능' in user_input or '주차가 불가' in user_input or '주차못' in user_input or '주차 못' in user_input:
        filtered_data = filtered_data[filtered_data['parking'] == False]

    if '블론드' in user_input or '블론드 라떼' in user_input or '블론드 에스프레소' in user_input or '블론드 원두' in user_input:
        filtered_data = filtered_data[filtered_data['blonde'] == True]
    if '블론드 아닌' in user_input or '블론드 제외' in user_input or '블론드 제외한' in user_input or '블론드 없는' in user_input:
        filtered_data = filtered_data[filtered_data['blonde'] == False]

    if '피지오' in user_input or '피지오 드링크' in user_input or '피지오 음료' in user_input or '피지오 커피' in user_input:
        filtered_data = filtered_data[filtered_data['physio'] == True]
    if '피지오 아닌' in user_input or '피지오 제외' in user_input or '피지오 제외한' in user_input or '피지오 없는' in user_input:
        filtered_data = filtered_data[filtered_data['physio'] == False]

    if '콜드브루' in user_input or '콜드 브루' in user_input or '콜드브루 커피' in user_input or '콜드 브루 커피' in user_input:
        filtered_data = filtered_data[filtered_data['coldbrew'] == True]
    if '콜드브루 아닌' in user_input or '콜드브루 제외' in user_input or '콜드브루 제외한' in user_input or '콜드브루 없는' in user_input:
        filtered_data = filtered_data[filtered_data['coldbrew'] == False]

    if '현금불가' in user_input or '현금 불가' in user_input or '현금 사용 불가' in user_input or '현금 받지 않는' in user_input:
        filtered_data = filtered_data[filtered_data['noCash'] == True]
    if '현금가능' in user_input or '현금 가능' in user_input or '현금 사용 가능' in user_input or '현금 받는' in user_input:
        filtered_data = filtered_data[filtered_data['noCash'] == False]

    if '외화결제' in user_input or '외화 결제' in user_input or '외국 화폐 결제' in user_input or '외화 사용 가능' in user_input:
        filtered_data = filtered_data[filtered_data['foreignCash'] == True]
    if '외화결제 불가' in user_input or '외화 결제 불가' in user_input or '외국 화폐 사용 불가' in user_input or '외화 사용 불가능' in user_input:
        filtered_data = filtered_data[filtered_data['foreignCash'] == False]

    if '딜리버스' in user_input or '딜리버리' in user_input or '배달 가능한' in user_input or '배달 되는' in user_input:
        filtered_data = filtered_data[filtered_data['deliBus'] == True]
    if '딜리버스 아닌' in user_input or '딜리버리 불가' in user_input or '배달 불가' in user_input or '배달 안되는' in user_input:
        filtered_data = filtered_data[filtered_data['deliBus'] == False]

    if '친환경'in user_input or 'in코'in user_input or '환경 친화적'in user_input or '환경 보호'in user_input:
        filtered_data = filtered_data[filtered_data['eco'] == True]
    if '친환경 아닌'in user_input or 'in코 아닌'in user_input or '환경 친화적 아닌'in user_input or '환경 보호 아닌'in user_input:
        filtered_data = filtered_data[filtered_data['eco'] == False]

    if '오후9시이후영업'in user_input or '야간영업'in user_input or '밤에 여는'in user_input or '밤늦게 여는'in user_input:
        filtered_data = filtered_data[filtered_data['close21'] == True]
    if '오후9시이후영업 아닌'in user_input or '야간영업 불가'in user_input or '밤에 닫는'in user_input or '일찍 닫는'in user_input:
        filtered_data = filtered_data[filtered_data['close21'] == False]

    if '펫존'in user_input or '반려동물 존'in user_input or '애완동물 존'in user_input or '반려동물 공간'in user_input:
        filtered_data = filtered_data[filtered_data['petZone'] == True]
    if '펫존 아닌'in user_input or '반려동물 존 아닌'in user_input or '애완동물 존 아닌'in user_input or '반려동물 공간 아닌'in user_input:
        filtered_data = filtered_data[filtered_data['petZone'] == False]

    if '공항'in user_input or '공항 근처'in user_input or '공항 근방'in user_input or '공항 주변'in user_input:
        filtered_data = filtered_data[filtered_data['airport'] == True]
    if '공항 아닌'in user_input or '공항 근처 아닌'in user_input or '공항 근방 아닌'in user_input or '공항 주변 아닌'in user_input:
        filtered_data = filtered_data[filtered_data['airport'] == False]

    if '해변가'in user_input or '바닷가'in user_input or '바다 근처'in user_input or '해안가'in user_input:
        filtered_data = filtered_data[filtered_data['seaside'] == True]
    if '해변가 아닌'in user_input or '바닷가 아닌'in user_input or '바다 근처 아닌'in user_input or '해안가 아닌'in user_input:
        filtered_data = filtered_data[filtered_data['seaside'] == False]

    if '대학교'in user_input or '대학'in user_input or '대학 근처'in user_input or '학교 근처'in user_input:
        filtered_data = filtered_data[filtered_data['university'] == True]
    if '대학교 아닌'in user_input or '대학 아닌'in user_input or '대학 근처 아닌'in user_input or '학교 근처 아닌'in user_input:
        filtered_data = filtered_data[filtered_data['university'] == False]

    if '터미널'in user_input or '버스터미널'in user_input or '터미널 근처'in user_input or '터미널 주변'in user_input:
        filtered_data = filtered_data[filtered_data['terminal'] == True]
    if '터미널 아닌'in user_input or '버스터미널 아닌'in user_input or '터미널 근처 아닌'in user_input or '터미널 주변 아닌'in user_input:
        filtered_data = filtered_data[filtered_data['terminal'] == False]

    if '리조트'in user_input or '리조트 근처'in user_input or '리조트 주변'in user_input or '휴양지'in user_input:
        filtered_data = filtered_data[filtered_data['resort'] == True]
    if '리조트 아닌'in user_input or '리조트 근처 아닌'in user_input or '리조트 주변 아닌'in user_input or '휴양지 아닌'in user_input:
        filtered_data = filtered_data[filtered_data['resort'] == False]

    if '병원'in user_input or '병원 근처'in user_input or '의료기관'in user_input or '의료시설'in user_input:
        filtered_data = filtered_data[filtered_data['hospital'] == True]
    if '병원 아닌'in user_input or '병원 근처 아닌'in user_input or '의료기관 아닌'in user_input or '의료시설 아닌'in user_input:
        filtered_data = filtered_data[filtered_data['hospital'] == False]

    if '매장내'in user_input or '매장 내'in user_input or '가게 안'in user_input or '상점 내'in user_input:
        filtered_data = filtered_data[filtered_data['inStore'] == True]
    if '매장내 아닌'in user_input or '매장 내 아닌'in user_input or '가게 안 아닌'in user_input or '상점 내 아닌'in user_input:
        filtered_data = filtered_data[filtered_data['inStore'] == False]

    if '지하철' in user_input or '지하철역' in user_input or '지하철 근처' in user_input or '지하철 주변' in user_input:
        filtered_data = filtered_data[filtered_data['subway'] == True]
    if '지하철 아닌' in user_input or '지하철역 아닌' in user_input or '지하철 근처 아닌' in user_input or '지하철 주변 아닌' in user_input:
        filtered_data = filtered_data[filtered_data['subway'] == False]

    if '장애인편의시설' in user_input or '장애인 편의 시설' in user_input or '장애인 접근 가능' in user_input or '장애인 지원' in user_input:
        filtered_data = filtered_data[filtered_data['theDisabled'] == True]
    if '장애인편의시설 아닌' in user_input or '장애인 편의 시설 아닌' in user_input or '장애인 접근 불가' in user_input or '장애인 지원 불가' in user_input:
        filtered_data = filtered_data[filtered_data['theDisabled'] == False]

    if '공기청정기' in user_input or 'in어 클리너' in user_input or '공기 청정' in user_input or '공기 정화' in user_input:
        filtered_data = filtered_data[filtered_data['airCleaner'] == True]
    if '공기청정기 없는' in user_input or 'in어 클리너 없는' in user_input or '공기 청정 안 되는' in user_input or '공기 정화 안 되는' in user_input:
        filtered_data = filtered_data[filtered_data['airCleaner'] == False]

    if '전기차충전소' in user_input or '전기차 충전' in user_input or 'EV 충전' in user_input or '전기차 충전 가능' in user_input:
        filtered_data = filtered_data[filtered_data['electricVehicleCharging'] == True]
    if '전기차충전소 없는' in user_input or '전기차 충전 안 되는' in user_input or 'EV 충전 불가' in user_input or '전기차 충전 불가능' in user_input:
        filtered_data = filtered_data[filtered_data['electricVehicleCharging'] == False]

    return filtered_data

# 입력 해시를 생성하는 함수
def generate_input_hash(user_input):
    return hashlib.md5(user_input.encode()).hexdigest()

# 캐시된 결과를 저장하는 함수
def save_to_cache(input_hash, results):
    cache_file_path = os.path.join(CACHE_DIR, f"{input_hash}.json")
    with open(cache_file_path, 'w') as cache_file:
        json.dump(results, cache_file)

# 캐시된 결과를 불러오는 함수
def load_from_cache(input_hash):
    cache_file_path = os.path.join(CACHE_DIR, f"{input_hash}.json")
    if os.path.exists(cache_file_path):
        with open(cache_file_path, 'r') as cache_file:
            return json.load(cache_file)
    return None

class UserInput(BaseModel):
    description: str

@app.post("/recommend/")
def recommend_stores(user_input: UserInput):
    start_time = time.time()  # 시간 측정 시작

    # 사용자 입력 해시 생성
    input_hash = generate_input_hash(user_input.description)
    
    # 캐시된 결과 불러오기 시도
    cached_results = load_from_cache(input_hash)
    if cached_results:
        return cached_results

    # 사용자 입력에서 명사 추출
    nouns = extract_nouns(user_input.description)
    if not nouns:
        raise HTTPException(status_code=400, detail="No valid nouns extracted from user input.")
    
    # 사용자 입력 명사 임베딩
    user_embeddings = get_embeddings_with_cache(nouns)
    
    # 원본 데이터 로드
    file_path = './data/스타벅스추천모델빈도.csv'  # 이 경로를 실제 데이터 파일 경로로 수정하세요.
    data = pd.read_csv(file_path)
    
    # 데이터 필터링
    filtered_data = filter_data(data, user_input.description)
    
    # 각 매장의 유사도 계산
    store_scores = []
    for index, row in filtered_data.iterrows():
        frequency_dict = ast.literal_eval(row['frequency'])
        store_score = 0
        
        for noun, freq in frequency_dict.items():
            if noun in embedding_cache:
                word_embedding = embedding_cache[noun]
            else:
                word_embedding = get_embeddings_with_cache([noun])[0]
            
            similarities = cosine_similarity(user_embeddings, [word_embedding])
            max_similarity = similarities.max()
            
            if max_similarity >= 0.98:  # 유사도 기준치
                store_score += freq
        
        store_scores.append(store_score)
        
        # 매장 유사도 계산 중간 결과 출력
        print(f"매장 {index} - 점수: {store_score}")
    
    # 각 매장의 점수를 데이터프레임에 추가
    filtered_data['score'] = store_scores
    
    # 추천 매장 정렬
    recommended_stores = filtered_data.sort_values(by='score', ascending=False)
    
    end_time = time.time()  # 시간 측정 종료
    print(f"추천 계산에 소요된 시간: {end_time - start_time:.2f}초")

    # 추천 결과 저장
    results = recommended_stores[['Store_Name', 'score']].head(10).to_dict(orient='records')
    save_to_cache(input_hash, results)

    # 추천 결과 반환
    return results

if __name__ == "__main__":
    uvicorn.run(app, host="127.0.0.1", port=8000)
# Out:
# Using device: mps
# KoBERT 모델과 토크나이저 로드 완료
# INFO:     Started server process [13587]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# Task exception was never retrieved
# future: <Task finished name='Task-4' coro=<Server.serve() done, defined at /opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/uvicorn/server.py:67> exception=KeyboardInterrupt()>
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/7z/q611htmn79g71769fkrcqrxm0000gn/T/ipykernel_13587/123446189.py", line 603, in <module>
#     uvicorn.run(app, host="127.0.0.1", port=8000)
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/uvicorn/main.py", line 577, in run
#     server.run()
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/uvicorn/server.py", line 65, in run
#     return asyncio.run(self.serve(sockets=sockets))
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/nest_asyncio.py", line 30, in run
#     return loop.run_until_complete(task)
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/nest_asyncio.py", line 92, in run_until_complete
#     self._run_once()
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/nest_asyncio.py", line 133, in _run_once
#     handle._run()
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/asyncio/tasks.py", line 339, in __wakeup
#     self.__step()
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/asyncio/tasks.py", line 256, in __step
#     result = coro.send(None)
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/uvicorn/server.py", line 69, in serve
#     await self._serve(sockets)
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/contextlib.py", line 126, in __exit__
#     next(self.gen)
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/uvicorn/server.py", line 328, in capture_signals
#     signal.raise_signal(captured_signal)
# KeyboardInterrupt
# 매장 0 - 점수: 1138
# 매장 1 - 점수: 448
# 매장 2 - 점수: 661
# 매장 3 - 점수: 1323
# 매장 4 - 점수: 2010
# 매장 5 - 점수: 522
# 매장 6 - 점수: 416
# 매장 7 - 점수: 1114
# 매장 8 - 점수: 1215
# 매장 9 - 점수: 484
# 매장 10 - 점수: 969
# 매장 11 - 점수: 755
# 매장 12 - 점수: 497
# 매장 13 - 점수: 804
# 매장 14 - 점수: 689
# 매장 15 - 점수: 767
# 매장 16 - 점수: 1006
# 매장 17 - 점수: 772
# 매장 18 - 점수: 687
# 매장 19 - 점수: 800
# 매장 20 - 점수: 1148
# 매장 21 - 점수: 731
# 매장 22 - 점수: 879
# 매장 23 - 점수: 1384
# 매장 24 - 점수: 955
# 매장 25 - 점수: 987
# 매장 26 - 점수: 634
# 매장 27 - 점수: 905
# 매장 28 - 점수: 705
# 매장 29 - 점수: 979
# 매장 30 - 점수: 485
# 매장 31 - 점수: 610
# 매장 32 - 점수: 630
# 매장 33 - 점수: 977
# 매장 34 - 점수: 781
# 매장 35 - 점수: 1020
# 매장 36 - 점수: 771
# 매장 37 - 점수: 1062
# 매장 38 - 점수: 687
# 매장 39 - 점수: 883
# 매장 40 - 점수: 1033
# 매장 41 - 점수: 773
# 매장 42 - 점수: 882
# 매장 43 - 점수: 837
# 매장 44 - 점수: 1102
# 매장 45 - 점수: 1500
# 매장 46 - 점수: 898
# 매장 47 - 점수: 1111
# 매장 48 - 점수: 1362
# 매장 49 - 점수: 921
# 매장 50 - 점수: 1385
# 매장 51 - 점수: 557
# 매장 52 - 점수: 1344
# 매장 53 - 점수: 1149
# 매장 54 - 점수: 727
# 매장 55 - 점수: 627
# 매장 56 - 점수: 652
# 매장 57 - 점수: 821
# 매장 58 - 점수: 714
# 매장 59 - 점수: 468
# 매장 60 - 점수: 930
# 매장 61 - 점수: 1054
# 매장 62 - 점수: 347
# 매장 63 - 점수: 1002
# 매장 64 - 점수: 993
# 매장 65 - 점수: 883
# 매장 66 - 점수: 953
# 매장 67 - 점수: 713
# 매장 68 - 점수: 786
# 매장 69 - 점수: 752
# 매장 70 - 점수: 462
# 매장 71 - 점수: 1074
# 매장 72 - 점수: 788
# 매장 73 - 점수: 1275
# 매장 74 - 점수: 756
# 매장 75 - 점수: 924
# 매장 76 - 점수: 793
# 매장 77 - 점수: 1016
# 매장 78 - 점수: 728
# 매장 79 - 점수: 919
# 매장 80 - 점수: 692
# 매장 81 - 점수: 611
# 매장 82 - 점수: 1111
# 매장 83 - 점수: 730
# 매장 84 - 점수: 1608
# 매장 85 - 점수: 937
# 매장 86 - 점수: 923
# 매장 87 - 점수: 893
# 매장 88 - 점수: 895
# 매장 89 - 점수: 1026
# 매장 90 - 점수: 1094
# 매장 91 - 점수: 404
# 매장 92 - 점수: 1017
# 매장 93 - 점수: 1197
# 매장 94 - 점수: 695
# 매장 95 - 점수: 1022
# 매장 96 - 점수: 791
# 매장 97 - 점수: 1078
# 매장 98 - 점수: 616
# 매장 99 - 점수: 1426
# 매장 100 - 점수: 1093
# 매장 101 - 점수: 1193
# 매장 102 - 점수: 1718
# 매장 103 - 점수: 779
# 매장 104 - 점수: 550
# 매장 105 - 점수: 1139
# 매장 106 - 점수: 1196
# 매장 107 - 점수: 474
# 매장 108 - 점수: 600
# 매장 109 - 점수: 708
# 매장 110 - 점수: 755
# 매장 111 - 점수: 977
# 매장 112 - 점수: 697
# 매장 113 - 점수: 612
# 매장 114 - 점수: 1229
# 매장 115 - 점수: 978
# 매장 116 - 점수: 993
# 매장 117 - 점수: 838
# 매장 118 - 점수: 1328
# 매장 119 - 점수: 1432
# 매장 120 - 점수: 634
# 매장 121 - 점수: 598
# 매장 122 - 점수: 1140
# 매장 123 - 점수: 798
# 매장 124 - 점수: 901
# 매장 125 - 점수: 637
# 매장 126 - 점수: 1311
# 매장 127 - 점수: 802
# 매장 128 - 점수: 906
# 매장 129 - 점수: 1144
# 매장 130 - 점수: 717
# 매장 131 - 점수: 1012
# 매장 132 - 점수: 1130
# 매장 133 - 점수: 1033
# 매장 134 - 점수: 1003
# 매장 135 - 점수: 838
# 매장 136 - 점수: 639
# 매장 137 - 점수: 729
# 매장 138 - 점수: 1233
# 매장 139 - 점수: 1376
# 매장 140 - 점수: 848
# 매장 141 - 점수: 633
# 매장 142 - 점수: 969
# 매장 143 - 점수: 2119
# 매장 144 - 점수: 1294
# 매장 145 - 점수: 795
# 매장 146 - 점수: 626
# 매장 147 - 점수: 521
# 매장 148 - 점수: 1226
# 매장 149 - 점수: 1202
# 매장 150 - 점수: 738
# 매장 151 - 점수: 712
# 매장 152 - 점수: 574
# 매장 153 - 점수: 537
# 매장 154 - 점수: 1114
# 매장 155 - 점수: 1086
# 매장 156 - 점수: 1000
# 매장 157 - 점수: 957
# 매장 158 - 점수: 1464
# 매장 159 - 점수: 1419
# 매장 160 - 점수: 958
# 매장 161 - 점수: 1388
# 매장 162 - 점수: 1031
# 매장 163 - 점수: 929
# 매장 164 - 점수: 288
# 매장 165 - 점수: 1345
# 매장 166 - 점수: 658
# 매장 167 - 점수: 857
# 매장 168 - 점수: 1144
# 매장 169 - 점수: 1601
# 매장 170 - 점수: 804
# 매장 171 - 점수: 768
# 매장 172 - 점수: 1063
# 매장 173 - 점수: 636
# 매장 174 - 점수: 846
# 매장 175 - 점수: 908
# 매장 176 - 점수: 994
# 매장 177 - 점수: 778
# 매장 178 - 점수: 740
# 매장 179 - 점수: 996
# 매장 180 - 점수: 1149
# 매장 181 - 점수: 804
# 매장 182 - 점수: 584
# 매장 183 - 점수: 726
# 매장 184 - 점수: 459
# 매장 185 - 점수: 167
# 매장 186 - 점수: 519
# 매장 187 - 점수: 806
# 매장 188 - 점수: 850
# 매장 189 - 점수: 683
# 매장 190 - 점수: 774
# 매장 191 - 점수: 967
# 매장 192 - 점수: 1095
# 매장 193 - 점수: 1577
# 매장 194 - 점수: 355
# 매장 195 - 점수: 821
# 매장 196 - 점수: 1053
# 매장 197 - 점수: 842
# 매장 198 - 점수: 932
# 매장 199 - 점수: 778
# 매장 200 - 점수: 990
# 매장 201 - 점수: 587
# 매장 202 - 점수: 449
# 매장 203 - 점수: 444
# 매장 204 - 점수: 888
# 매장 205 - 점수: 804
# 매장 206 - 점수: 1156
# 매장 207 - 점수: 1242
# 매장 208 - 점수: 515
# 매장 209 - 점수: 1225
# 매장 210 - 점수: 1253
# 매장 211 - 점수: 809
# 매장 212 - 점수: 1199
# 매장 213 - 점수: 842
# 매장 214 - 점수: 1376
# 매장 215 - 점수: 601
# 매장 216 - 점수: 985
# 매장 217 - 점수: 629
# 매장 218 - 점수: 794
# 매장 219 - 점수: 863
# 매장 220 - 점수: 730
# 매장 221 - 점수: 980
# 매장 222 - 점수: 2040
# 매장 223 - 점수: 1105
# 매장 224 - 점수: 729
# 매장 225 - 점수: 1299
# 매장 226 - 점수: 885
# 매장 227 - 점수: 922
# 매장 228 - 점수: 876
# 매장 229 - 점수: 431
# 매장 230 - 점수: 621
# 매장 231 - 점수: 417
# 매장 232 - 점수: 1402
# 매장 233 - 점수: 1043
# 매장 234 - 점수: 665
# 매장 235 - 점수: 1982
# 매장 236 - 점수: 1526
# 매장 237 - 점수: 1599
# 매장 238 - 점수: 701
# 매장 239 - 점수: 1121
# 매장 240 - 점수: 603
# 매장 241 - 점수: 1475
# 매장 242 - 점수: 632
# 매장 243 - 점수: 934
# 매장 244 - 점수: 1342
# 매장 245 - 점수: 811
# 매장 246 - 점수: 799
# 매장 247 - 점수: 715
# 매장 248 - 점수: 1000
# 매장 249 - 점수: 1412
# 매장 250 - 점수: 936
# 매장 251 - 점수: 1411
# 매장 252 - 점수: 930
# 매장 253 - 점수: 645
# 매장 254 - 점수: 558
# 매장 255 - 점수: 946
# 매장 256 - 점수: 599
# 매장 257 - 점수: 783
# 매장 258 - 점수: 1015
# 매장 259 - 점수: 1113
# 매장 260 - 점수: 1587
# 매장 261 - 점수: 1049
# 매장 262 - 점수: 924
# 매장 263 - 점수: 1010
# 매장 264 - 점수: 558
# 매장 265 - 점수: 701
# 매장 266 - 점수: 960
# 매장 267 - 점수: 752
# 매장 268 - 점수: 546
# 매장 269 - 점수: 781
# 매장 270 - 점수: 706
# 매장 271 - 점수: 487
# 매장 272 - 점수: 771
# 매장 273 - 점수: 691
# 매장 274 - 점수: 700
# 매장 275 - 점수: 1119
# 매장 276 - 점수: 687
# 매장 277 - 점수: 965
# 매장 278 - 점수: 1516
# 매장 279 - 점수: 1083
# 매장 280 - 점수: 751
# 매장 281 - 점수: 736
# 매장 282 - 점수: 923
# 매장 283 - 점수: 252
# 매장 284 - 점수: 911
# 매장 285 - 점수: 492
# 매장 286 - 점수: 651
# 매장 287 - 점수: 637
# 매장 288 - 점수: 844
# 매장 289 - 점수: 1061
# 매장 290 - 점수: 1342
# 매장 291 - 점수: 745
# 매장 292 - 점수: 759
# 매장 293 - 점수: 687
# 매장 294 - 점수: 946
# 매장 295 - 점수: 852
# 매장 296 - 점수: 1098
# 매장 297 - 점수: 901
# 매장 298 - 점수: 899
# 매장 299 - 점수: 1184
# 매장 300 - 점수: 988
# 매장 301 - 점수: 1038
# 매장 302 - 점수: 810
# 매장 303 - 점수: 695
# 매장 304 - 점수: 839
# 매장 305 - 점수: 670
# 매장 306 - 점수: 658
# 매장 307 - 점수: 1293
# 매장 308 - 점수: 1041
# 매장 309 - 점수: 774
# 매장 310 - 점수: 904
# 매장 311 - 점수: 811
# 매장 312 - 점수: 990
# 매장 313 - 점수: 1353
# 매장 314 - 점수: 699
# 매장 315 - 점수: 1435
# 매장 316 - 점수: 1086
# 매장 317 - 점수: 771
# 매장 318 - 점수: 720
# 매장 319 - 점수: 1083
# 매장 320 - 점수: 1500
# 매장 321 - 점수: 1193
# 매장 322 - 점수: 819
# 매장 323 - 점수: 999
# 매장 324 - 점수: 718
# 매장 325 - 점수: 894
# 매장 326 - 점수: 930
# 매장 327 - 점수: 1547
# 매장 328 - 점수: 888
# 매장 329 - 점수: 896
# 매장 330 - 점수: 1405
# 매장 331 - 점수: 680
# 매장 332 - 점수: 786
# 매장 333 - 점수: 382
# 매장 334 - 점수: 348
# 매장 335 - 점수: 996
# 매장 336 - 점수: 804
# 매장 337 - 점수: 1170
# 매장 338 - 점수: 1260
# 매장 339 - 점수: 898
# 매장 340 - 점수: 1113
# 매장 341 - 점수: 1435
# 매장 342 - 점수: 877
# 매장 343 - 점수: 976
# 매장 344 - 점수: 1373
# 매장 345 - 점수: 617
# 매장 346 - 점수: 1151
# 매장 347 - 점수: 863
# 매장 348 - 점수: 853
# 매장 349 - 점수: 426
# 매장 350 - 점수: 566
# 매장 351 - 점수: 1179
# 매장 352 - 점수: 632
# 매장 353 - 점수: 990
# 매장 354 - 점수: 1323
# 매장 355 - 점수: 892
# 매장 356 - 점수: 734
# 매장 357 - 점수: 1077
# 매장 358 - 점수: 863
# 매장 359 - 점수: 705
# 매장 360 - 점수: 906
# 매장 361 - 점수: 779
# 매장 362 - 점수: 1059
# 매장 363 - 점수: 483
# 매장 364 - 점수: 698
# 매장 365 - 점수: 1121
# 매장 366 - 점수: 306
# 매장 367 - 점수: 823
# 매장 368 - 점수: 899
# 매장 369 - 점수: 1013
# 매장 370 - 점수: 707
# 매장 371 - 점수: 533
# 매장 372 - 점수: 1311
# 매장 373 - 점수: 870
# 매장 374 - 점수: 993
# 매장 375 - 점수: 1190
# 매장 376 - 점수: 564
# 매장 377 - 점수: 1136
# 매장 378 - 점수: 978
# 매장 379 - 점수: 631
# 매장 380 - 점수: 891
# 매장 381 - 점수: 859
# 매장 382 - 점수: 822
# 매장 383 - 점수: 963
# 매장 384 - 점수: 805
# 매장 385 - 점수: 1145
# 매장 386 - 점수: 552
# 매장 387 - 점수: 706
# 매장 388 - 점수: 859
# 매장 389 - 점수: 1237
# 매장 390 - 점수: 949
# 매장 391 - 점수: 1624
# 매장 392 - 점수: 1257
# 매장 393 - 점수: 1269
# 매장 394 - 점수: 577
# 매장 395 - 점수: 983
# 매장 396 - 점수: 795
# 매장 397 - 점수: 1170
# 매장 398 - 점수: 1425
# 매장 399 - 점수: 1167
# 매장 400 - 점수: 1192
# 매장 401 - 점수: 1334
# 매장 402 - 점수: 876
# 매장 403 - 점수: 691
# 매장 404 - 점수: 913
# 매장 405 - 점수: 1298
# 매장 406 - 점수: 1117
# 매장 407 - 점수: 780
# 매장 408 - 점수: 1046
# 매장 409 - 점수: 1095
# 매장 410 - 점수: 399
# 매장 411 - 점수: 1090
# 매장 412 - 점수: 1133
# 매장 413 - 점수: 1287
# 매장 414 - 점수: 936
# 매장 415 - 점수: 1624
# 매장 416 - 점수: 1325
# 매장 417 - 점수: 971
# 매장 418 - 점수: 1254
# 매장 419 - 점수: 835
# 매장 420 - 점수: 577
# 매장 421 - 점수: 777
# 매장 422 - 점수: 1004
# 매장 423 - 점수: 961
# 매장 424 - 점수: 743
# 매장 425 - 점수: 1107
# 매장 426 - 점수: 1181
# 매장 427 - 점수: 1522
# 매장 428 - 점수: 1033
# 매장 429 - 점수: 1085
# 매장 430 - 점수: 595
# 매장 431 - 점수: 891
# 매장 432 - 점수: 888
# 매장 433 - 점수: 805
# 매장 434 - 점수: 665
# 매장 435 - 점수: 1210
# 매장 436 - 점수: 1152
# 매장 437 - 점수: 1741
# 매장 438 - 점수: 1016
# 매장 439 - 점수: 1267
# 매장 440 - 점수: 972
# 매장 441 - 점수: 922
# 매장 442 - 점수: 1173
# 매장 443 - 점수: 974
# 매장 444 - 점수: 1012
# 매장 445 - 점수: 1050
# 매장 446 - 점수: 971
# 매장 447 - 점수: 1070
# 매장 448 - 점수: 779
# 매장 449 - 점수: 1474
# 매장 450 - 점수: 1111
# 매장 451 - 점수: 851
# 매장 452 - 점수: 1180
# 매장 453 - 점수: 1315
# 매장 454 - 점수: 1082
# 매장 455 - 점수: 699
# 매장 456 - 점수: 801
# 매장 457 - 점수: 982
# 매장 458 - 점수: 1090
# 매장 459 - 점수: 542
# 매장 460 - 점수: 862
# 매장 461 - 점수: 882
# 매장 462 - 점수: 479
# 매장 463 - 점수: 1031
# 매장 464 - 점수: 991
# 매장 465 - 점수: 711
# 매장 466 - 점수: 805
# 매장 467 - 점수: 542
# 매장 468 - 점수: 467
# 매장 469 - 점수: 875
# 매장 470 - 점수: 750
# 매장 471 - 점수: 513
# 매장 472 - 점수: 812
# 매장 473 - 점수: 1425
# 매장 474 - 점수: 774
# 매장 475 - 점수: 1072
# 매장 476 - 점수: 772
# 매장 477 - 점수: 660
# 매장 478 - 점수: 781
# 매장 479 - 점수: 796
# 매장 480 - 점수: 650
# 매장 481 - 점수: 688
# 매장 482 - 점수: 880
# 매장 483 - 점수: 860
# 매장 484 - 점수: 858
# 매장 485 - 점수: 996
# 매장 486 - 점수: 1333
# 매장 487 - 점수: 1546
# 매장 488 - 점수: 854
# 매장 489 - 점수: 1232
# 매장 490 - 점수: 1620
# 매장 491 - 점수: 1115
# 매장 492 - 점수: 1247
# 매장 493 - 점수: 742
# 매장 494 - 점수: 681
# 매장 495 - 점수: 957
# 매장 496 - 점수: 457
# 매장 497 - 점수: 1008
# 매장 498 - 점수: 858
# 매장 499 - 점수: 537
# 매장 500 - 점수: 845
# 매장 501 - 점수: 736
# 매장 502 - 점수: 1227
# 매장 503 - 점수: 1297
# 매장 504 - 점수: 484
# 매장 505 - 점수: 1275
# 매장 506 - 점수: 656
# 매장 507 - 점수: 766
# 매장 508 - 점수: 932
# 매장 509 - 점수: 896
# 매장 510 - 점수: 718
# 매장 511 - 점수: 1023
# 매장 512 - 점수: 822
# 매장 513 - 점수: 510
# 매장 514 - 점수: 1030
# 매장 515 - 점수: 852
# 매장 516 - 점수: 712
# 매장 517 - 점수: 396
# 매장 518 - 점수: 682
# 매장 519 - 점수: 1028
# 매장 520 - 점수: 310
# 매장 521 - 점수: 870
# 매장 522 - 점수: 875
# 매장 523 - 점수: 928
# 매장 524 - 점수: 1035
# 매장 525 - 점수: 1292
# 매장 526 - 점수: 1535
# 매장 527 - 점수: 2000
# 매장 528 - 점수: 1861
# 매장 529 - 점수: 1847
# 매장 530 - 점수: 1701
# 매장 531 - 점수: 1425
# 매장 532 - 점수: 850
# 매장 533 - 점수: 477
# 매장 534 - 점수: 413
# 매장 535 - 점수: 1002
# 매장 536 - 점수: 928
# 매장 537 - 점수: 900
# 매장 538 - 점수: 895
# 매장 539 - 점수: 817
# 매장 540 - 점수: 1295
# 매장 541 - 점수: 832
# 매장 542 - 점수: 427
# 매장 543 - 점수: 936
# 매장 544 - 점수: 811
# 매장 545 - 점수: 1302
# 매장 546 - 점수: 636
# 매장 547 - 점수: 709
# 매장 548 - 점수: 911
# 매장 549 - 점수: 782
# 매장 550 - 점수: 760
# 매장 551 - 점수: 816
# 매장 552 - 점수: 1040
# 매장 553 - 점수: 478
# 매장 554 - 점수: 1192
# 매장 555 - 점수: 1282
# 매장 556 - 점수: 1009
# 매장 557 - 점수: 711
# 매장 558 - 점수: 785
# 매장 559 - 점수: 771
# 매장 560 - 점수: 751
# 매장 561 - 점수: 1586
# 매장 562 - 점수: 1398
# 매장 563 - 점수: 140
# 매장 564 - 점수: 1025
# 매장 565 - 점수: 827
# 매장 566 - 점수: 946
# 매장 567 - 점수: 780
# 매장 568 - 점수: 1047
# 매장 569 - 점수: 872
# 매장 570 - 점수: 663
# 매장 571 - 점수: 619
# 매장 572 - 점수: 221
# 매장 573 - 점수: 1193
# 매장 574 - 점수: 774
# 매장 575 - 점수: 848
# 매장 576 - 점수: 509
# 매장 577 - 점수: 1240
# 매장 578 - 점수: 947
# 매장 579 - 점수: 1269
# 매장 580 - 점수: 1305
# 매장 581 - 점수: 974
# 매장 582 - 점수: 1355
# 매장 583 - 점수: 758
# 매장 584 - 점수: 1490
# 매장 585 - 점수: 844
# 매장 586 - 점수: 1498
# 매장 587 - 점수: 669
# 매장 588 - 점수: 913
# 매장 589 - 점수: 822
# 매장 590 - 점수: 1161
# 매장 591 - 점수: 868
# 매장 592 - 점수: 946
# 매장 593 - 점수: 790
# 매장 594 - 점수: 1059
# 매장 595 - 점수: 1669
# 매장 596 - 점수: 1193
# 매장 597 - 점수: 964
# 매장 598 - 점수: 770
# 매장 599 - 점수: 608
# 매장 600 - 점수: 901
# 매장 601 - 점수: 496
# 매장 602 - 점수: 759
# 매장 603 - 점수: 627
# 매장 604 - 점수: 464
# 매장 605 - 점수: 788
# 매장 606 - 점수: 753
# 매장 607 - 점수: 859
# 매장 608 - 점수: 393
# 매장 609 - 점수: 818
# 매장 610 - 점수: 1134
# 매장 611 - 점수: 730
# 매장 612 - 점수: 1462
# 매장 613 - 점수: 1349
# 매장 614 - 점수: 891
# 매장 615 - 점수: 1441
# 매장 616 - 점수: 1423
# 매장 617 - 점수: 1258
# 매장 618 - 점수: 955
# 매장 619 - 점수: 741
# 매장 620 - 점수: 691
# 매장 621 - 점수: 885
# 매장 622 - 점수: 926
# 매장 623 - 점수: 819
# 매장 624 - 점수: 1258
# 매장 625 - 점수: 930
# 매장 626 - 점수: 732
# 매장 627 - 점수: 789
# 매장 628 - 점수: 1069
# 매장 629 - 점수: 1073
# 매장 630 - 점수: 1015
# 매장 631 - 점수: 568
# 매장 632 - 점수: 580
# 매장 633 - 점수: 1226
# 매장 634 - 점수: 623
# 매장 635 - 점수: 725
# 매장 636 - 점수: 695
# 매장 637 - 점수: 870
# 매장 638 - 점수: 1295
# 매장 639 - 점수: 893
# 매장 640 - 점수: 716
# 매장 641 - 점수: 843
# 매장 642 - 점수: 727
# 매장 643 - 점수: 820
# 매장 644 - 점수: 794
# 매장 645 - 점수: 555
# 매장 646 - 점수: 708
# 매장 647 - 점수: 598
# 매장 648 - 점수: 1406
# 매장 649 - 점수: 1345
# 매장 650 - 점수: 820
# 매장 651 - 점수: 1029
# 매장 652 - 점수: 793
# 매장 653 - 점수: 815
# 매장 654 - 점수: 503
# 매장 655 - 점수: 489
# 매장 656 - 점수: 838
# 매장 657 - 점수: 1333
# 매장 658 - 점수: 1142
# 매장 659 - 점수: 546
# 매장 660 - 점수: 1181
# 매장 661 - 점수: 707
# 매장 662 - 점수: 751
# 매장 663 - 점수: 890
# 매장 664 - 점수: 726
# 매장 665 - 점수: 859
# 매장 666 - 점수: 328
# 매장 667 - 점수: 824
# 매장 668 - 점수: 770
# 매장 669 - 점수: 563
# 매장 670 - 점수: 1502
# 매장 671 - 점수: 289
# 매장 672 - 점수: 766
# 매장 673 - 점수: 856
# 매장 674 - 점수: 870
# 매장 675 - 점수: 979
# 매장 676 - 점수: 1190
# 매장 677 - 점수: 473
# 매장 678 - 점수: 1264
# 매장 679 - 점수: 913
# 매장 680 - 점수: 1252
# 매장 681 - 점수: 859
# 매장 682 - 점수: 900
# 매장 683 - 점수: 1106
# 매장 684 - 점수: 559
# 매장 685 - 점수: 737
# 매장 686 - 점수: 350
# 매장 687 - 점수: 651
# 매장 688 - 점수: 761
# 매장 689 - 점수: 825
# 매장 690 - 점수: 888
# 매장 691 - 점수: 764
# 매장 692 - 점수: 670
# 매장 693 - 점수: 923
# 매장 694 - 점수: 893
# 매장 695 - 점수: 794
# 매장 696 - 점수: 915
# 매장 697 - 점수: 1086
# 매장 698 - 점수: 1092
# 매장 699 - 점수: 346
# 매장 700 - 점수: 496
# 매장 701 - 점수: 1103
# 매장 702 - 점수: 983
# 매장 703 - 점수: 1250
# 매장 704 - 점수: 819
# 매장 705 - 점수: 498
# 매장 706 - 점수: 1260
# 매장 707 - 점수: 715
# 매장 708 - 점수: 798
# 매장 709 - 점수: 882
# 매장 710 - 점수: 556
# 매장 711 - 점수: 632
# 매장 712 - 점수: 693
# 매장 713 - 점수: 1094
# 매장 714 - 점수: 1026
# 매장 715 - 점수: 622
# 매장 716 - 점수: 919
# 매장 717 - 점수: 608
# 매장 718 - 점수: 1147
# 매장 719 - 점수: 1058
# 매장 720 - 점수: 916
# 매장 721 - 점수: 1022
# 매장 722 - 점수: 690
# 매장 723 - 점수: 376
# 매장 724 - 점수: 1125
# 매장 725 - 점수: 671
# 매장 726 - 점수: 878
# 매장 727 - 점수: 1235
# 매장 728 - 점수: 1267
# 매장 729 - 점수: 776
# 매장 730 - 점수: 591
# 매장 731 - 점수: 535
# 매장 732 - 점수: 932
# 매장 733 - 점수: 1132
# 매장 734 - 점수: 476
# 매장 735 - 점수: 780
# 매장 736 - 점수: 1007
# 매장 737 - 점수: 1246
# 매장 738 - 점수: 1276
# 매장 739 - 점수: 462
# 매장 740 - 점수: 892
# 매장 741 - 점수: 1222
# 매장 742 - 점수: 978
# 매장 743 - 점수: 689
# 매장 744 - 점수: 495
# 매장 745 - 점수: 945
# 매장 746 - 점수: 832
# 매장 747 - 점수: 1556
# 매장 748 - 점수: 763
# 매장 749 - 점수: 833
# 매장 750 - 점수: 811
# 매장 751 - 점수: 768
# 매장 752 - 점수: 1056
# 매장 753 - 점수: 815
# 매장 754 - 점수: 797
# 매장 755 - 점수: 890
# 매장 756 - 점수: 1092
# 매장 757 - 점수: 1431
# 매장 758 - 점수: 824
# 매장 759 - 점수: 1117
# 매장 760 - 점수: 887
# 매장 761 - 점수: 1173
# 매장 762 - 점수: 818
# 매장 763 - 점수: 468
# 매장 764 - 점수: 1379
# 매장 765 - 점수: 870
# 매장 766 - 점수: 1156
# 매장 767 - 점수: 697
# 매장 768 - 점수: 906
# 매장 769 - 점수: 919
# 매장 770 - 점수: 1070
# 매장 771 - 점수: 1394
# 매장 772 - 점수: 856
# 매장 773 - 점수: 1156
# 매장 774 - 점수: 688
# 매장 775 - 점수: 1431
# 매장 776 - 점수: 1203
# 매장 777 - 점수: 1068
# 매장 778 - 점수: 853
# 매장 779 - 점수: 927
# 매장 780 - 점수: 1114
# 매장 781 - 점수: 1025
# 매장 782 - 점수: 1232
# 매장 783 - 점수: 896
# 매장 784 - 점수: 782
# 매장 785 - 점수: 556
# 매장 786 - 점수: 738
# 매장 787 - 점수: 927
# 매장 788 - 점수: 971
# 매장 789 - 점수: 1111
# 매장 790 - 점수: 1425
# 매장 791 - 점수: 937
# 매장 792 - 점수: 775
# 매장 793 - 점수: 1003
# 매장 794 - 점수: 135
# 매장 795 - 점수: 1005
# 매장 796 - 점수: 858
# 매장 797 - 점수: 1168
# 매장 798 - 점수: 872
# 매장 799 - 점수: 872
# 매장 800 - 점수: 1079
# 매장 801 - 점수: 792
# 매장 802 - 점수: 207
# 매장 803 - 점수: 394
# 매장 804 - 점수: 526
# 매장 805 - 점수: 498
# 매장 806 - 점수: 808
# 매장 807 - 점수: 1689
# 매장 808 - 점수: 675
# 매장 809 - 점수: 1019
# 매장 810 - 점수: 800
# 매장 811 - 점수: 1109
# 매장 812 - 점수: 550
# 매장 813 - 점수: 749
# 매장 814 - 점수: 910
# 매장 815 - 점수: 1382
# 매장 816 - 점수: 881
# 매장 817 - 점수: 768
# 매장 818 - 점수: 987
# 매장 819 - 점수: 82
# 매장 820 - 점수: 757
# 매장 821 - 점수: 544
# 매장 822 - 점수: 751
# 매장 823 - 점수: 810
# 매장 824 - 점수: 1249
# 매장 825 - 점수: 882
# 매장 826 - 점수: 530
# 매장 827 - 점수: 690
# 매장 828 - 점수: 572
# 매장 829 - 점수: 224
# 매장 830 - 점수: 893
# 매장 831 - 점수: 812
# 매장 832 - 점수: 1082
# 매장 833 - 점수: 992
# 매장 834 - 점수: 279
# 매장 835 - 점수: 1024
# 매장 836 - 점수: 1309
# 매장 837 - 점수: 802
# 매장 838 - 점수: 995
# 매장 839 - 점수: 766
# 매장 840 - 점수: 750
# 매장 841 - 점수: 526
# 매장 842 - 점수: 941
# 매장 843 - 점수: 578
# 매장 844 - 점수: 1013
# 매장 845 - 점수: 1224
# 매장 846 - 점수: 677
# 매장 847 - 점수: 647
# 매장 848 - 점수: 993
# 매장 849 - 점수: 612
# 매장 850 - 점수: 917
# 매장 851 - 점수: 647
# 매장 852 - 점수: 1122
# 매장 853 - 점수: 1070
# 매장 854 - 점수: 1128
# 매장 855 - 점수: 1088
# 매장 856 - 점수: 669
# 매장 857 - 점수: 691
# 매장 858 - 점수: 590
# 매장 859 - 점수: 804
# 매장 860 - 점수: 819
# 매장 861 - 점수: 607
# 매장 862 - 점수: 1379
# 매장 863 - 점수: 1840
# 매장 864 - 점수: 777
# 매장 865 - 점수: 787
# 매장 866 - 점수: 1224
# 매장 867 - 점수: 972
# 매장 868 - 점수: 852
# 매장 869 - 점수: 959
# 매장 870 - 점수: 709
# 매장 871 - 점수: 1000
# 매장 872 - 점수: 629
# 매장 873 - 점수: 462
# 매장 874 - 점수: 575
# 매장 875 - 점수: 809
# 매장 876 - 점수: 777
# 매장 877 - 점수: 1785
# 매장 878 - 점수: 883
# 매장 879 - 점수: 992
# 매장 880 - 점수: 1085
# 매장 881 - 점수: 771
# 매장 882 - 점수: 1219
# 매장 883 - 점수: 999
# 매장 884 - 점수: 1031
# 매장 885 - 점수: 683
# 매장 886 - 점수: 716
# 매장 887 - 점수: 1090
# 매장 888 - 점수: 583
# 매장 889 - 점수: 1015
# 매장 890 - 점수: 1069
# 매장 891 - 점수: 623
# 매장 892 - 점수: 934
# 매장 893 - 점수: 1374
# 매장 894 - 점수: 1273
# 매장 895 - 점수: 496
# 매장 896 - 점수: 983
# 매장 897 - 점수: 767
# 매장 898 - 점수: 1303
# 매장 899 - 점수: 699
# 매장 900 - 점수: 1051
# 매장 901 - 점수: 600
# 매장 902 - 점수: 1058
# 매장 903 - 점수: 530
# 매장 904 - 점수: 804
# 매장 905 - 점수: 478
# 매장 906 - 점수: 1014
# 매장 907 - 점수: 385
# 매장 908 - 점수: 557
# 매장 909 - 점수: 588
# 매장 910 - 점수: 723
# 매장 911 - 점수: 733
# 매장 912 - 점수: 408
# 매장 913 - 점수: 614
# 매장 914 - 점수: 801
# 매장 915 - 점수: 480
# 매장 916 - 점수: 897
# 매장 917 - 점수: 1355
# 매장 918 - 점수: 1011
# 매장 919 - 점수: 977
# 매장 920 - 점수: 839
# 매장 921 - 점수: 719
# 매장 922 - 점수: 676
# 매장 923 - 점수: 694
# 매장 924 - 점수: 575
# 매장 925 - 점수: 1592
# 매장 926 - 점수: 874
# 매장 927 - 점수: 826
# 매장 928 - 점수: 1133
# 매장 929 - 점수: 825
# 매장 930 - 점수: 803
# 매장 931 - 점수: 1021
# 매장 932 - 점수: 1476
# 매장 933 - 점수: 1034
# 매장 934 - 점수: 970
# 매장 935 - 점수: 953
# 매장 936 - 점수: 875
# 매장 937 - 점수: 1135
# 매장 938 - 점수: 1984
# 매장 939 - 점수: 1793
# 매장 940 - 점수: 1043
# 매장 941 - 점수: 1044
# 매장 942 - 점수: 1044
# 매장 943 - 점수: 1115
# 매장 944 - 점수: 1083
# 매장 945 - 점수: 955
# 매장 946 - 점수: 895
# 매장 947 - 점수: 729
# 매장 948 - 점수: 890
# 매장 949 - 점수: 515
# 매장 950 - 점수: 519
# 매장 951 - 점수: 813
# 매장 952 - 점수: 573
# 매장 953 - 점수: 1077
# 매장 954 - 점수: 453
# 매장 955 - 점수: 433
# 매장 956 - 점수: 942
# 매장 957 - 점수: 573
# 매장 958 - 점수: 695
# 매장 959 - 점수: 709
# 매장 960 - 점수: 964
# 매장 961 - 점수: 1046
# 매장 962 - 점수: 1134
# 매장 963 - 점수: 649
# 매장 964 - 점수: 1461
# 매장 965 - 점수: 625
# 매장 966 - 점수: 1360
# 매장 967 - 점수: 539
# 매장 968 - 점수: 1144
# 매장 969 - 점수: 1105
# 매장 970 - 점수: 1112
# 매장 971 - 점수: 1324
# 매장 972 - 점수: 1269
# 매장 973 - 점수: 784
# 매장 974 - 점수: 948
# 매장 975 - 점수: 647
# 매장 976 - 점수: 937
# 매장 977 - 점수: 657
# 매장 978 - 점수: 570
# 매장 979 - 점수: 1103
# 매장 980 - 점수: 1407
# 매장 981 - 점수: 844
# 매장 982 - 점수: 840
# 매장 983 - 점수: 514
# 매장 984 - 점수: 868
# 매장 985 - 점수: 1726
# 매장 986 - 점수: 944
# 매장 987 - 점수: 1139
# 매장 988 - 점수: 919
# 매장 989 - 점수: 999
# 매장 990 - 점수: 687
# 매장 991 - 점수: 736
# 매장 992 - 점수: 1044
# 매장 993 - 점수: 864
# 매장 994 - 점수: 811
# 매장 995 - 점수: 897
# 매장 996 - 점수: 996
# 매장 997 - 점수: 602
# 매장 998 - 점수: 582
# 매장 999 - 점수: 1184
# 매장 1000 - 점수: 932
# 매장 1001 - 점수: 440
# 매장 1002 - 점수: 591
# 매장 1003 - 점수: 1730
# 매장 1004 - 점수: 1081
# 매장 1005 - 점수: 1289
# 매장 1006 - 점수: 1123
# 매장 1007 - 점수: 752
# 매장 1008 - 점수: 884
# 매장 1009 - 점수: 1090
# 매장 1010 - 점수: 622
# 매장 1011 - 점수: 907
# 매장 1012 - 점수: 1075
# 매장 1013 - 점수: 1182
# 매장 1014 - 점수: 1398
# 매장 1015 - 점수: 619
# 매장 1016 - 점수: 829
# 매장 1017 - 점수: 770
# 매장 1018 - 점수: 1107
# 매장 1019 - 점수: 1000
# 매장 1020 - 점수: 729
# 매장 1021 - 점수: 650
# 매장 1022 - 점수: 512
# 매장 1023 - 점수: 606
# 매장 1024 - 점수: 929
# 매장 1025 - 점수: 1464
# 매장 1026 - 점수: 1464
# 매장 1027 - 점수: 991
# 매장 1028 - 점수: 855
# 매장 1029 - 점수: 840
# 매장 1030 - 점수: 685
# 매장 1031 - 점수: 859
# 매장 1032 - 점수: 1191
# 매장 1033 - 점수: 1023
# 매장 1034 - 점수: 804
# 매장 1035 - 점수: 804
# 매장 1036 - 점수: 972
# 매장 1037 - 점수: 737
# 매장 1038 - 점수: 887
# 매장 1039 - 점수: 477
# 매장 1040 - 점수: 1045
# 매장 1041 - 점수: 1155
# 매장 1042 - 점수: 1639
# 매장 1043 - 점수: 898
# 매장 1044 - 점수: 1016
# 매장 1045 - 점수: 652
# 매장 1046 - 점수: 745
# 매장 1047 - 점수: 779
# 매장 1048 - 점수: 580
# 매장 1049 - 점수: 803
# 매장 1050 - 점수: 989
# 매장 1051 - 점수: 820
# 매장 1052 - 점수: 822
# 매장 1053 - 점수: 635
# 매장 1054 - 점수: 946
# 매장 1055 - 점수: 645
# 매장 1056 - 점수: 739
# 매장 1057 - 점수: 744
# 매장 1058 - 점수: 342
# 매장 1059 - 점수: 1347
# 매장 1060 - 점수: 595
# 매장 1061 - 점수: 827
# 매장 1062 - 점수: 619
# 매장 1063 - 점수: 1197
# 매장 1064 - 점수: 605
# 매장 1065 - 점수: 479
# 매장 1066 - 점수: 458
# 매장 1067 - 점수: 433
# 매장 1068 - 점수: 1342
# 매장 1069 - 점수: 1480
# 매장 1070 - 점수: 662
# 매장 1071 - 점수: 747
# 매장 1072 - 점수: 662
# 매장 1073 - 점수: 564
# 매장 1074 - 점수: 859
# 매장 1075 - 점수: 984
# 매장 1076 - 점수: 1049
# 매장 1077 - 점수: 1407
# 매장 1078 - 점수: 453
# 매장 1079 - 점수: 680
# 매장 1080 - 점수: 1036
# 매장 1081 - 점수: 995
# 매장 1082 - 점수: 1232
# 매장 1083 - 점수: 720
# 매장 1084 - 점수: 1061
# 매장 1085 - 점수: 1134
# 매장 1086 - 점수: 852
# 매장 1087 - 점수: 891
# 매장 1088 - 점수: 857
# 매장 1089 - 점수: 704
# 매장 1090 - 점수: 1259
# 매장 1091 - 점수: 946
# 매장 1092 - 점수: 1516
# 매장 1093 - 점수: 1086
# 매장 1094 - 점수: 800
# 매장 1095 - 점수: 892
# 매장 1096 - 점수: 978
# 매장 1097 - 점수: 788
# 매장 1098 - 점수: 989
# 매장 1099 - 점수: 710
# 매장 1100 - 점수: 890
# 매장 1101 - 점수: 1253
# 매장 1102 - 점수: 1228
# 매장 1103 - 점수: 903
# 매장 1104 - 점수: 757
# 매장 1105 - 점수: 1014
# 매장 1106 - 점수: 601
# 매장 1107 - 점수: 1032
# 매장 1108 - 점수: 1340
# 매장 1109 - 점수: 748
# 매장 1110 - 점수: 665
# 매장 1111 - 점수: 1408
# 매장 1112 - 점수: 1007
# 매장 1113 - 점수: 1393
# 매장 1114 - 점수: 722
# 매장 1115 - 점수: 927
# 매장 1116 - 점수: 767
# 매장 1117 - 점수: 672
# 매장 1118 - 점수: 657
# 매장 1119 - 점수: 855
# 매장 1120 - 점수: 279
# 매장 1121 - 점수: 1513
# 매장 1122 - 점수: 759
# 매장 1123 - 점수: 404
# 매장 1124 - 점수: 944
# 매장 1125 - 점수: 938
# 매장 1126 - 점수: 965
# 매장 1127 - 점수: 1071
# 매장 1128 - 점수: 874
# 매장 1129 - 점수: 977
# 매장 1130 - 점수: 1000
# 매장 1131 - 점수: 634
# 매장 1132 - 점수: 941
# 매장 1133 - 점수: 501
# 매장 1134 - 점수: 899
# 매장 1135 - 점수: 926
# 매장 1136 - 점수: 742
# 매장 1137 - 점수: 1075
# 매장 1138 - 점수: 1146
# 매장 1139 - 점수: 718
# 매장 1140 - 점수: 774
# 매장 1141 - 점수: 911
# 매장 1142 - 점수: 770
# 매장 1143 - 점수: 940
# 매장 1144 - 점수: 372
# 매장 1145 - 점수: 1097
# 매장 1146 - 점수: 1189
# 매장 1147 - 점수: 518
# 매장 1148 - 점수: 713
# 매장 1149 - 점수: 846
# 매장 1150 - 점수: 712
# 매장 1151 - 점수: 790
# 매장 1152 - 점수: 909
# 매장 1153 - 점수: 602
# 매장 1154 - 점수: 591
# 매장 1155 - 점수: 1262
# 매장 1156 - 점수: 1059
# 매장 1157 - 점수: 539
# 매장 1158 - 점수: 687
# 매장 1159 - 점수: 438
# 매장 1160 - 점수: 652
# 매장 1161 - 점수: 958
# 매장 1162 - 점수: 1865
# 매장 1163 - 점수: 924
# 매장 1164 - 점수: 1087
# 매장 1165 - 점수: 555
# 매장 1166 - 점수: 1277
# 매장 1167 - 점수: 739
# 매장 1168 - 점수: 246
# 매장 1169 - 점수: 777
# 매장 1170 - 점수: 782
# 매장 1171 - 점수: 1211
# 매장 1172 - 점수: 662
# 매장 1173 - 점수: 777
# 매장 1174 - 점수: 493
# 매장 1175 - 점수: 766
# 매장 1176 - 점수: 1179
# 매장 1177 - 점수: 704
# 매장 1178 - 점수: 981
# 매장 1179 - 점수: 872
# 매장 1180 - 점수: 1228
# 매장 1181 - 점수: 1132
# 매장 1182 - 점수: 1296
# 매장 1183 - 점수: 906
# 매장 1184 - 점수: 512
# 매장 1185 - 점수: 1120
# 매장 1186 - 점수: 1072
# 매장 1187 - 점수: 1574
# 매장 1188 - 점수: 447
# 매장 1189 - 점수: 631
# 매장 1190 - 점수: 1157
# 매장 1191 - 점수: 755
# 매장 1192 - 점수: 1113
# 매장 1193 - 점수: 923
# 매장 1194 - 점수: 670
# 매장 1195 - 점수: 851
# 매장 1196 - 점수: 703
# 매장 1197 - 점수: 859
# 매장 1198 - 점수: 598
# 매장 1199 - 점수: 1386
# 매장 1200 - 점수: 596
# 매장 1201 - 점수: 1088
# 매장 1202 - 점수: 927
# 매장 1203 - 점수: 635
# 매장 1204 - 점수: 771
# 매장 1205 - 점수: 675
# 매장 1206 - 점수: 1059
# 매장 1207 - 점수: 1264
# 매장 1208 - 점수: 1026
# 매장 1209 - 점수: 800
# 매장 1210 - 점수: 945
# 매장 1211 - 점수: 699
# 매장 1212 - 점수: 981
# 매장 1213 - 점수: 824
# 매장 1214 - 점수: 925
# 매장 1215 - 점수: 1070
# 매장 1216 - 점수: 1251
# 매장 1217 - 점수: 1014
# 매장 1218 - 점수: 895
# 매장 1219 - 점수: 787
# 매장 1220 - 점수: 888
# 매장 1221 - 점수: 1018
# 매장 1222 - 점수: 1293
# 매장 1223 - 점수: 906
# 매장 1224 - 점수: 768
# 매장 1225 - 점수: 1285
# 매장 1226 - 점수: 557
# 매장 1227 - 점수: 511
# 매장 1228 - 점수: 1539
# 매장 1229 - 점수: 1007
# 매장 1230 - 점수: 1433
# 매장 1231 - 점수: 684
# 매장 1232 - 점수: 685
# 매장 1233 - 점수: 960
# 매장 1234 - 점수: 827
# 매장 1235 - 점수: 1027
# 매장 1236 - 점수: 1242
# 매장 1237 - 점수: 1224
# 매장 1238 - 점수: 905
# 매장 1239 - 점수: 568
# 매장 1240 - 점수: 1064
# 매장 1241 - 점수: 833
# 매장 1242 - 점수: 284
# 매장 1243 - 점수: 900
# 매장 1244 - 점수: 192
# 매장 1245 - 점수: 539
# 매장 1246 - 점수: 1172
# 매장 1247 - 점수: 1564
# 매장 1248 - 점수: 889
# 매장 1249 - 점수: 731
# 매장 1250 - 점수: 1535
# 매장 1251 - 점수: 1701
# 매장 1252 - 점수: 1092
# 매장 1253 - 점수: 711
# 매장 1254 - 점수: 638
# 매장 1255 - 점수: 599
# 매장 1256 - 점수: 837
# 매장 1257 - 점수: 635
# 매장 1258 - 점수: 777
# 매장 1259 - 점수: 1013
# 매장 1260 - 점수: 503
# 매장 1261 - 점수: 788
# 매장 1262 - 점수: 728
# 매장 1263 - 점수: 1047
# 매장 1264 - 점수: 670
# 매장 1265 - 점수: 491
# 매장 1266 - 점수: 1260
# 매장 1267 - 점수: 334
# 매장 1268 - 점수: 1051
# 매장 1269 - 점수: 1494
# 매장 1270 - 점수: 742
# 매장 1271 - 점수: 593
# 매장 1272 - 점수: 1391
# 매장 1273 - 점수: 779
# 매장 1274 - 점수: 998
# 매장 1275 - 점수: 519
# 매장 1276 - 점수: 671
# 매장 1277 - 점수: 864
# 매장 1278 - 점수: 337
# 매장 1279 - 점수: 41
# 매장 1280 - 점수: 690
# 매장 1281 - 점수: 593
# 매장 1282 - 점수: 865
# 매장 1283 - 점수: 1314
# 매장 1284 - 점수: 890
# 매장 1285 - 점수: 677
# 매장 1286 - 점수: 1036
# 매장 1287 - 점수: 503
# 매장 1288 - 점수: 941
# 매장 1289 - 점수: 571
# 매장 1290 - 점수: 903
# 매장 1291 - 점수: 985
# 매장 1292 - 점수: 1302
# 매장 1293 - 점수: 1281
# 매장 1294 - 점수: 1292
# 매장 1295 - 점수: 1346
# 매장 1296 - 점수: 1357
# 매장 1297 - 점수: 734
# 매장 1298 - 점수: 680
# 매장 1299 - 점수: 956
# 매장 1300 - 점수: 1117
# 매장 1301 - 점수: 984
# 매장 1302 - 점수: 766
# 매장 1303 - 점수: 1033
# 매장 1304 - 점수: 1252
# 매장 1305 - 점수: 1254
# 매장 1306 - 점수: 508
# 매장 1307 - 점수: 1306
# 매장 1308 - 점수: 539
# 매장 1309 - 점수: 1225
# 매장 1310 - 점수: 813
# 매장 1311 - 점수: 956
# 매장 1312 - 점수: 886
# 매장 1313 - 점수: 1075
# 매장 1314 - 점수: 893
# 매장 1315 - 점수: 862
# 매장 1316 - 점수: 881
# 매장 1317 - 점수: 693
# 매장 1318 - 점수: 689
# 매장 1319 - 점수: 294
# 매장 1320 - 점수: 680
# 매장 1321 - 점수: 421
# 매장 1322 - 점수: 1022
# 매장 1323 - 점수: 1581
# 매장 1324 - 점수: 456
# 매장 1325 - 점수: 745
# 매장 1326 - 점수: 693
# 매장 1327 - 점수: 1087
# 매장 1328 - 점수: 1678
# 매장 1329 - 점수: 1204
# 매장 1330 - 점수: 714
# 매장 1331 - 점수: 508
# 매장 1332 - 점수: 1089
# 매장 1333 - 점수: 1540
# 매장 1334 - 점수: 901
# 매장 1335 - 점수: 417
# 매장 1336 - 점수: 1159
# 매장 1337 - 점수: 1273
# 매장 1338 - 점수: 721
# 매장 1339 - 점수: 852
# 매장 1340 - 점수: 1132
# 매장 1341 - 점수: 1202
# 매장 1342 - 점수: 790
# 매장 1343 - 점수: 866
# 매장 1344 - 점수: 986
# 매장 1345 - 점수: 815
# 매장 1346 - 점수: 843
# 매장 1347 - 점수: 1181
# 매장 1348 - 점수: 746
# 매장 1349 - 점수: 1431
# 매장 1350 - 점수: 1269
# 매장 1351 - 점수: 772
# 매장 1352 - 점수: 536
# 매장 1353 - 점수: 894
# 매장 1354 - 점수: 818
# 매장 1355 - 점수: 1113
# 매장 1356 - 점수: 953
# 매장 1357 - 점수: 705
# 매장 1358 - 점수: 1003
# 매장 1359 - 점수: 650
# 매장 1360 - 점수: 1106
# 매장 1361 - 점수: 1436
# 매장 1362 - 점수: 733
# 매장 1363 - 점수: 824
# 매장 1364 - 점수: 1159
# 매장 1365 - 점수: 648
# 매장 1366 - 점수: 556
# 매장 1367 - 점수: 926
# 매장 1368 - 점수: 426
# 매장 1369 - 점수: 1099
# 매장 1370 - 점수: 765
# 매장 1371 - 점수: 872
# 매장 1372 - 점수: 816
# 매장 1373 - 점수: 431
# 매장 1374 - 점수: 1006
# 매장 1375 - 점수: 629
# 매장 1376 - 점수: 866
# 매장 1377 - 점수: 636
# 매장 1378 - 점수: 846
# 매장 1379 - 점수: 901
# 매장 1380 - 점수: 1013
# 매장 1381 - 점수: 803
# 매장 1382 - 점수: 772
# 매장 1383 - 점수: 1370
# 매장 1384 - 점수: 940
# 매장 1385 - 점수: 1271
# 매장 1386 - 점수: 761
# 매장 1387 - 점수: 577
# 매장 1388 - 점수: 943
# 매장 1389 - 점수: 1549
# 매장 1390 - 점수: 1221
# 매장 1391 - 점수: 966
# 매장 1392 - 점수: 1051
# 매장 1393 - 점수: 944
# 매장 1394 - 점수: 841
# 매장 1395 - 점수: 1107
# 매장 1396 - 점수: 730
# 매장 1397 - 점수: 1012
# 매장 1398 - 점수: 1281
# 매장 1399 - 점수: 1080
# 매장 1400 - 점수: 432
# 매장 1401 - 점수: 997
# 매장 1402 - 점수: 1008
# 매장 1403 - 점수: 849
# 매장 1404 - 점수: 587
# 매장 1405 - 점수: 680
# 매장 1406 - 점수: 722
# 매장 1407 - 점수: 825
# 매장 1408 - 점수: 431
# 매장 1409 - 점수: 873
# 매장 1410 - 점수: 871
# 매장 1411 - 점수: 578
# 매장 1412 - 점수: 940
# 매장 1413 - 점수: 1104
# 매장 1414 - 점수: 1482
# 매장 1415 - 점수: 722
# 매장 1416 - 점수: 1105
# 매장 1417 - 점수: 602
# 매장 1418 - 점수: 779
# 매장 1419 - 점수: 714
# 매장 1420 - 점수: 870
# 매장 1421 - 점수: 522
# 매장 1422 - 점수: 658
# 매장 1423 - 점수: 718
# 매장 1424 - 점수: 1520
# 매장 1425 - 점수: 1065
# 매장 1426 - 점수: 507
# 매장 1427 - 점수: 1208
# 매장 1428 - 점수: 924
# 매장 1429 - 점수: 704
# 매장 1430 - 점수: 793
# 매장 1431 - 점수: 1180
# 매장 1432 - 점수: 803
# 매장 1433 - 점수: 621
# 매장 1434 - 점수: 865
# 매장 1435 - 점수: 1061
# 매장 1436 - 점수: 834
# 매장 1437 - 점수: 1103
# 매장 1438 - 점수: 875
# 매장 1439 - 점수: 1100
# 매장 1440 - 점수: 597
# 매장 1441 - 점수: 923
# 매장 1442 - 점수: 968
# 매장 1443 - 점수: 674
# 매장 1444 - 점수: 415
# 매장 1445 - 점수: 869
# 매장 1446 - 점수: 884
# 매장 1447 - 점수: 925
# 매장 1448 - 점수: 1090
# 매장 1449 - 점수: 1050
# 매장 1450 - 점수: 786
# 매장 1451 - 점수: 821
# 매장 1452 - 점수: 566
# 매장 1453 - 점수: 1106
# 매장 1454 - 점수: 1152
# 매장 1455 - 점수: 1449
# 매장 1456 - 점수: 810
# 매장 1457 - 점수: 1219
# 매장 1458 - 점수: 906
# 매장 1459 - 점수: 841
# 매장 1460 - 점수: 1303
# 매장 1461 - 점수: 743
# 매장 1462 - 점수: 1215
# 매장 1463 - 점수: 640
# 매장 1464 - 점수: 1442
# 매장 1465 - 점수: 802
# 매장 1466 - 점수: 1304
# 매장 1467 - 점수: 1063
# 매장 1468 - 점수: 1249
# 매장 1469 - 점수: 1330
# 매장 1470 - 점수: 804
# 매장 1471 - 점수: 246
# 매장 1472 - 점수: 501
# 매장 1473 - 점수: 616
# 매장 1474 - 점수: 972
# 매장 1475 - 점수: 1596
# 매장 1476 - 점수: 1179
# 매장 1477 - 점수: 1003
# 매장 1478 - 점수: 1092
# 매장 1479 - 점수: 1391
# 매장 1480 - 점수: 1404
# 매장 1481 - 점수: 624
# 매장 1482 - 점수: 1104
# 매장 1483 - 점수: 1018
# 매장 1484 - 점수: 790
# 매장 1485 - 점수: 803
# 매장 1486 - 점수: 1119
# 매장 1487 - 점수: 893
# 매장 1488 - 점수: 1133
# 매장 1489 - 점수: 1206
# 매장 1490 - 점수: 1217
# 매장 1491 - 점수: 1092
# 매장 1492 - 점수: 808
# 매장 1493 - 점수: 949
# 매장 1494 - 점수: 627
# 매장 1495 - 점수: 455
# 매장 1496 - 점수: 890
# 매장 1497 - 점수: 1309
# 매장 1498 - 점수: 823
# 매장 1499 - 점수: 978
# 매장 1500 - 점수: 492
# 매장 1501 - 점수: 953
# 매장 1502 - 점수: 1155
# 매장 1503 - 점수: 894
# 매장 1504 - 점수: 1121
# 매장 1505 - 점수: 1006
# 매장 1506 - 점수: 1037
# 매장 1507 - 점수: 988
# 매장 1508 - 점수: 618
# 매장 1509 - 점수: 1010
# 매장 1510 - 점수: 715
# 매장 1511 - 점수: 652
# 매장 1512 - 점수: 763
# 매장 1513 - 점수: 799
# 매장 1514 - 점수: 401
# 매장 1515 - 점수: 842
# 매장 1516 - 점수: 620
# 매장 1517 - 점수: 950
# 매장 1518 - 점수: 689
# 매장 1519 - 점수: 900
# 매장 1520 - 점수: 561
# 매장 1521 - 점수: 650
# 매장 1522 - 점수: 660
# 매장 1523 - 점수: 760
# 매장 1524 - 점수: 935
# 매장 1525 - 점수: 461
# 매장 1526 - 점수: 877
# 매장 1527 - 점수: 796
# 매장 1528 - 점수: 1020
# 매장 1529 - 점수: 571
# 매장 1530 - 점수: 666
# 매장 1531 - 점수: 792
# 매장 1532 - 점수: 569
# 매장 1533 - 점수: 1042
# 매장 1534 - 점수: 737
# 매장 1535 - 점수: 681
# 매장 1536 - 점수: 939
# 매장 1537 - 점수: 949
# 매장 1538 - 점수: 692
# 매장 1539 - 점수: 674
# 매장 1540 - 점수: 797
# 매장 1541 - 점수: 996
# 매장 1542 - 점수: 888
# 매장 1543 - 점수: 1161
# 매장 1544 - 점수: 640
# 매장 1545 - 점수: 529
# 매장 1546 - 점수: 258
# 매장 1547 - 점수: 1024
# 매장 1548 - 점수: 1090
# 매장 1549 - 점수: 430
# 매장 1550 - 점수: 1016
# 매장 1551 - 점수: 880
# 매장 1552 - 점수: 538
# 매장 1553 - 점수: 807
# 매장 1554 - 점수: 894
# 매장 1555 - 점수: 686
# 매장 1556 - 점수: 871
# 매장 1557 - 점수: 1403
# 매장 1558 - 점수: 1012
# 매장 1559 - 점수: 489
# 매장 1560 - 점수: 1084
# 매장 1561 - 점수: 1114
# 매장 1562 - 점수: 1223
# 매장 1563 - 점수: 972
# 매장 1564 - 점수: 727
# 매장 1565 - 점수: 461
# 매장 1566 - 점수: 1069
# 매장 1567 - 점수: 897
# 매장 1568 - 점수: 961
# 매장 1569 - 점수: 407
# 매장 1570 - 점수: 859
# 매장 1571 - 점수: 386
# 매장 1572 - 점수: 233
# 매장 1573 - 점수: 324
# 매장 1574 - 점수: 977
# 매장 1575 - 점수: 827
# 매장 1576 - 점수: 265
# 매장 1577 - 점수: 691
# 매장 1578 - 점수: 1586
# 매장 1579 - 점수: 1429
# 매장 1580 - 점수: 499
# 매장 1581 - 점수: 1636
# 매장 1582 - 점수: 1543
# 매장 1583 - 점수: 1399
# 매장 1584 - 점수: 1119
# 매장 1585 - 점수: 1432
# 매장 1586 - 점수: 1538
# 매장 1587 - 점수: 1633
# 매장 1588 - 점수: 1530
# 매장 1589 - 점수: 1229
# 매장 1590 - 점수: 978
# 매장 1591 - 점수: 1332
# 매장 1592 - 점수: 1239
# 매장 1593 - 점수: 668
# 매장 1594 - 점수: 1511
# 매장 1595 - 점수: 1968
# 매장 1596 - 점수: 1197
# 매장 1597 - 점수: 1815
# 매장 1598 - 점수: 1688
# 매장 1599 - 점수: 1506
# 매장 1600 - 점수: 1264
# 매장 1601 - 점수: 1250
# 매장 1602 - 점수: 1563
# 매장 1603 - 점수: 1651
# 매장 1604 - 점수: 1294
# 매장 1605 - 점수: 1169
# 매장 1606 - 점수: 499
# 매장 1607 - 점수: 740
# 매장 1608 - 점수: 679
# 매장 1609 - 점수: 1373
# 매장 1610 - 점수: 422
# 매장 1611 - 점수: 931
# 매장 1612 - 점수: 518
# 매장 1613 - 점수: 1010
# 매장 1614 - 점수: 413
# 매장 1615 - 점수: 1530
# 매장 1616 - 점수: 811
# 매장 1617 - 점수: 379
# 매장 1618 - 점수: 748
# 매장 1619 - 점수: 803
# 매장 1620 - 점수: 462
# 매장 1621 - 점수: 664
# 매장 1622 - 점수: 843
# 매장 1623 - 점수: 996
# 매장 1624 - 점수: 590
# 매장 1625 - 점수: 866
# 매장 1626 - 점수: 749
# 매장 1627 - 점수: 1367
# 매장 1628 - 점수: 652
# 매장 1629 - 점수: 418
# 매장 1630 - 점수: 699
# 매장 1631 - 점수: 736
# 매장 1632 - 점수: 751
# 매장 1633 - 점수: 793
# 매장 1634 - 점수: 323
# 매장 1635 - 점수: 1217
# 매장 1636 - 점수: 472
# 매장 1637 - 점수: 520
# 매장 1638 - 점수: 487
# 매장 1639 - 점수: 386
# 매장 1640 - 점수: 973
# 매장 1641 - 점수: 905
# 매장 1642 - 점수: 619
# 매장 1643 - 점수: 997
# 매장 1644 - 점수: 1322
# 매장 1645 - 점수: 637
# 매장 1646 - 점수: 34
# 매장 1647 - 점수: 820
# 매장 1648 - 점수: 726
# 매장 1649 - 점수: 798
# 매장 1650 - 점수: 1002
# 매장 1651 - 점수: 1258
# 매장 1652 - 점수: 924
# 매장 1653 - 점수: 1452
# 매장 1654 - 점수: 881
# 매장 1655 - 점수: 905
# 매장 1656 - 점수: 423
# 매장 1657 - 점수: 1231
# 매장 1658 - 점수: 1327
# 매장 1659 - 점수: 746
# 매장 1660 - 점수: 1113
# 매장 1661 - 점수: 890
# 매장 1662 - 점수: 965
# 매장 1663 - 점수: 890
# 매장 1664 - 점수: 1381
# 매장 1665 - 점수: 1215
# 매장 1666 - 점수: 1072
# 매장 1667 - 점수: 1051
# 매장 1668 - 점수: 1090
# 매장 1669 - 점수: 1213
# 매장 1670 - 점수: 1348
# 매장 1671 - 점수: 972
# 매장 1672 - 점수: 819
# 매장 1673 - 점수: 960
# 매장 1674 - 점수: 1089
# 매장 1675 - 점수: 1066
# 매장 1676 - 점수: 908
# 매장 1677 - 점수: 936
# 매장 1678 - 점수: 758
# 매장 1679 - 점수: 1040
# 매장 1680 - 점수: 1059
# 매장 1681 - 점수: 982
# 매장 1682 - 점수: 883
# 매장 1683 - 점수: 898
# 매장 1684 - 점수: 940
# 매장 1685 - 점수: 1308
# 매장 1686 - 점수: 1125
# 매장 1687 - 점수: 1224
# 매장 1688 - 점수: 1315
# 매장 1689 - 점수: 896
# 매장 1690 - 점수: 700
# 매장 1691 - 점수: 1339
# 매장 1692 - 점수: 804
# 매장 1693 - 점수: 770
# 매장 1694 - 점수: 575
# 매장 1695 - 점수: 827
# 매장 1696 - 점수: 1069
# 매장 1697 - 점수: 697
# 매장 1698 - 점수: 1083
# 매장 1699 - 점수: 818
# 매장 1700 - 점수: 1215
# 매장 1701 - 점수: 1158
# 매장 1702 - 점수: 468
# 매장 1703 - 점수: 746
# 매장 1704 - 점수: 1060
# 매장 1705 - 점수: 916
# 매장 1706 - 점수: 1000
# 매장 1707 - 점수: 758
# 매장 1708 - 점수: 655
# 매장 1709 - 점수: 693
# 매장 1710 - 점수: 831
# 매장 1711 - 점수: 758
# 매장 1712 - 점수: 797
# 매장 1713 - 점수: 784
# 매장 1714 - 점수: 751
# 매장 1715 - 점수: 779
# 매장 1716 - 점수: 1113
# 매장 1717 - 점수: 1113
# 매장 1718 - 점수: 1002
# 매장 1719 - 점수: 1323
# 매장 1720 - 점수: 712
# 매장 1721 - 점수: 928
# 매장 1722 - 점수: 1407
# 매장 1723 - 점수: 1341
# 매장 1724 - 점수: 1131
# 매장 1725 - 점수: 1070
# 매장 1726 - 점수: 1599
# 매장 1727 - 점수: 526
# 매장 1728 - 점수: 805
# 매장 1729 - 점수: 662
# 매장 1730 - 점수: 683
# 매장 1731 - 점수: 794
# 매장 1732 - 점수: 1129
# 매장 1733 - 점수: 809
# 매장 1734 - 점수: 1299
# 매장 1735 - 점수: 715
# 매장 1736 - 점수: 1349
# 매장 1737 - 점수: 677
# 매장 1738 - 점수: 663
# 매장 1739 - 점수: 1031
# 매장 1740 - 점수: 685
# 매장 1741 - 점수: 1129
# 매장 1742 - 점수: 635
# 매장 1743 - 점수: 606
# 매장 1744 - 점수: 1141
# 매장 1745 - 점수: 951
# 매장 1746 - 점수: 479
# 매장 1747 - 점수: 762
# 매장 1748 - 점수: 602
# 매장 1749 - 점수: 599
# 매장 1750 - 점수: 1085
# 매장 1751 - 점수: 995
# 매장 1752 - 점수: 1133
# 매장 1753 - 점수: 882
# 매장 1754 - 점수: 516
# 매장 1755 - 점수: 651
# 매장 1756 - 점수: 446
# 매장 1757 - 점수: 965
# 매장 1758 - 점수: 627
# 매장 1759 - 점수: 1221
# 매장 1760 - 점수: 927
# 매장 1761 - 점수: 363
# 매장 1762 - 점수: 916
# 매장 1763 - 점수: 645
# 매장 1764 - 점수: 1161
# 매장 1765 - 점수: 1434
# 매장 1766 - 점수: 1309
# 매장 1767 - 점수: 773
# 매장 1768 - 점수: 940
# 매장 1769 - 점수: 916
# 매장 1770 - 점수: 1107
# 매장 1771 - 점수: 1030
# 매장 1772 - 점수: 1076
# 매장 1773 - 점수: 1212
# 매장 1774 - 점수: 787
# 매장 1775 - 점수: 1011
# 매장 1776 - 점수: 1087
# 매장 1777 - 점수: 1027
# 매장 1778 - 점수: 639
# 매장 1779 - 점수: 302
# 매장 1780 - 점수: 960
# 매장 1781 - 점수: 670
# 매장 1782 - 점수: 1262
# 매장 1783 - 점수: 1359
# 매장 1784 - 점수: 747
# 매장 1785 - 점수: 742
# 매장 1786 - 점수: 729
# 매장 1787 - 점수: 974
# 매장 1788 - 점수: 802
# 매장 1789 - 점수: 926
# 매장 1790 - 점수: 592
# 매장 1791 - 점수: 848
# 매장 1792 - 점수: 1321
# 매장 1793 - 점수: 958
# 매장 1794 - 점수: 607
# 매장 1795 - 점수: 1099
# 매장 1796 - 점수: 703
# 매장 1797 - 점수: 541
# 매장 1798 - 점수: 829
# 매장 1799 - 점수: 780
# 매장 1800 - 점수: 819
# 매장 1801 - 점수: 680
# 매장 1802 - 점수: 905
# 매장 1803 - 점수: 710
# 매장 1804 - 점수: 1543
# 매장 1805 - 점수: 1304
# 매장 1806 - 점수: 759
# 매장 1807 - 점수: 853
# 매장 1808 - 점수: 907
# 매장 1809 - 점수: 1489
# 매장 1810 - 점수: 918
# 매장 1811 - 점수: 990
# 매장 1812 - 점수: 878
# 매장 1813 - 점수: 580
# 매장 1814 - 점수: 1037
# 매장 1815 - 점수: 423
# 매장 1816 - 점수: 824
# 매장 1817 - 점수: 415
# 매장 1818 - 점수: 1437
# 매장 1819 - 점수: 832
# 매장 1820 - 점수: 1160
# 매장 1821 - 점수: 767
# 매장 1822 - 점수: 1025
# 매장 1823 - 점수: 339
# 매장 1824 - 점수: 734
# 매장 1825 - 점수: 817
# 매장 1826 - 점수: 1698
# 매장 1827 - 점수: 1070
# 매장 1828 - 점수: 456
# 매장 1829 - 점수: 818
# 매장 1830 - 점수: 1150
# 매장 1831 - 점수: 837
# 매장 1832 - 점수: 618
# 매장 1833 - 점수: 353
# 매장 1834 - 점수: 616
# 매장 1835 - 점수: 730
# 매장 1836 - 점수: 878
# 매장 1837 - 점수: 623
# 매장 1838 - 점수: 1169
# 매장 1839 - 점수: 1037
# 매장 1840 - 점수: 1045
# 매장 1841 - 점수: 749
# 매장 1842 - 점수: 315
# 매장 1843 - 점수: 720
# 매장 1844 - 점수: 696
# 매장 1845 - 점수: 763
# 매장 1846 - 점수: 855
# 매장 1847 - 점수: 1082
# 매장 1848 - 점수: 541
# 매장 1849 - 점수: 844
# 매장 1850 - 점수: 1041
# 매장 1851 - 점수: 598
# 매장 1852 - 점수: 844
# 매장 1853 - 점수: 1343
# 매장 1854 - 점수: 332
# 매장 1855 - 점수: 498
# 매장 1856 - 점수: 735
# 매장 1857 - 점수: 845
# 매장 1858 - 점수: 513
# 매장 1859 - 점수: 677
# 매장 1860 - 점수: 1395
# 매장 1861 - 점수: 785
# 매장 1862 - 점수: 1002
# 매장 1863 - 점수: 1026
# 매장 1864 - 점수: 1063
# 매장 1865 - 점수: 673
# 매장 1866 - 점수: 760
# 매장 1867 - 점수: 573
# 매장 1868 - 점수: 1334
# 매장 1869 - 점수: 765
# 매장 1870 - 점수: 904
# 매장 1871 - 점수: 996
# 매장 1872 - 점수: 873
# 매장 1873 - 점수: 1175
# 매장 1874 - 점수: 1199
# 매장 1875 - 점수: 981
# 매장 1876 - 점수: 431
# 매장 1877 - 점수: 1280
# 매장 1878 - 점수: 1201
# 매장 1879 - 점수: 819
# 매장 1880 - 점수: 1137
# 매장 1881 - 점수: 470
# 매장 1882 - 점수: 872
# 매장 1883 - 점수: 829
# 매장 1884 - 점수: 924
# 매장 1885 - 점수: 789
# 매장 1886 - 점수: 586
# 매장 1887 - 점수: 672
# 매장 1888 - 점수: 747
# 매장 1889 - 점수: 987
# 매장 1890 - 점수: 975
# 매장 1891 - 점수: 593
# 매장 1892 - 점수: 871
# 매장 1893 - 점수: 1275
# 매장 1894 - 점수: 519
# 매장 1895 - 점수: 650
# 매장 1896 - 점수: 824
# 매장 1897 - 점수: 809
# 매장 1898 - 점수: 706
# 매장 1899 - 점수: 1030
# 매장 1900 - 점수: 629
# 매장 1901 - 점수: 1052
# 매장 1902 - 점수: 1271
# 매장 1903 - 점수: 1092
# 매장 1904 - 점수: 848
# 매장 1905 - 점수: 1089
# 매장 1906 - 점수: 769
# 매장 1907 - 점수: 628
# 매장 1908 - 점수: 1118
# 매장 1909 - 점수: 1237
# 매장 1910 - 점수: 879
# 매장 1911 - 점수: 1317
# 매장 1912 - 점수: 1072
# 매장 1913 - 점수: 743
# 매장 1914 - 점수: 1242
# 매장 1915 - 점수: 787
# 매장 1916 - 점수: 914
# 매장 1917 - 점수: 1038
# 매장 1918 - 점수: 1351
# 매장 1919 - 점수: 1076
# 매장 1920 - 점수: 474
# 매장 1921 - 점수: 842
# 매장 1922 - 점수: 675
# 매장 1923 - 점수: 800
# 추천 계산에 소요된 시간: 337.52초
# INFO:     127.0.0.1:51338 - "POST /recommend/ HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [13587]
# Task exception was never retrieved
# future: <Task finished name='Task-14' coro=<Server.serve() done, defined at /opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/uvicorn/server.py:67> exception=KeyboardInterrupt()>
# Traceback (most recent call last):
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3550, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/7z/q611htmn79g71769fkrcqrxm0000gn/T/ipykernel_13587/123446189.py", line 603, in <module>
#     uvicorn.run(app, host="127.0.0.1", port=8000)
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/uvicorn/main.py", line 577, in run
#     server.run()
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/uvicorn/server.py", line 65, in run
#     return asyncio.run(self.serve(sockets=sockets))
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/nest_asyncio.py", line 30, in run
#     return loop.run_until_complete(task)
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/nest_asyncio.py", line 92, in run_until_complete
#     self._run_once()
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/nest_asyncio.py", line 133, in _run_once
#     handle._run()
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/asyncio/tasks.py", line 339, in __wakeup
#     self.__step()
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/asyncio/tasks.py", line 256, in __step
#     result = coro.send(None)
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/uvicorn/server.py", line 69, in serve
#     await self._serve(sockets)
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/contextlib.py", line 126, in __exit__
#     next(self.gen)
#   File "/opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/uvicorn/server.py", line 328, in capture_signals
#     signal.raise_signal(captured_signal)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 603
#     600     return results
#     602 if __name__ == "__main__":
# --> 603     uvicorn.run(app, host="127.0.0.1", port=8000)
#
# File /opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/uvicorn/main.py:577, in run(app, host, port, uds, fd, loop, http, ws, ws_max_size, ws_max_queue, ws_ping_interval, ws_ping_timeout, ws_per_message_deflate, lifespan, interface, reload, reload_dirs, reload_includes, reload_excludes, reload_delay, workers, env_file, log_config, log_level, access_log, proxy_headers, server_header, date_header, forwarded_allow_ips, root_path, limit_concurrency, backlog, limit_max_requests, timeout_keep_alive, timeout_graceful_shutdown, ssl_keyfile, ssl_certfile, ssl_keyfile_password, ssl_version, ssl_cert_reqs, ssl_ca_certs, ssl_ciphers, headers, use_colors, app_dir, factory, h11_max_incomplete_event_size)
#     575         Multiprocess(config, target=server.run, sockets=[sock]).run()
#     576     else:
# --> 577         server.run()
#     578 finally:
#     579     if config.uds and os.path.exists(config.uds):
#
# File /opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/uvicorn/server.py:65, in Server.run(self, sockets)
#      63 def run(self, sockets: list[socket.socket] | None = None) -> None:
#      64     self.config.setup_event_loop()
# ---> 65     return asyncio.run(self.serve(sockets=sockets))
#
# File /opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File /opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File /opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/nest_asyncio.py:133, in _patch_loop.<locals>._run_once(self)
#     130 curr_task = curr_tasks.pop(self, None)
#     132 try:
# --> 133     handle._run()
#     134 finally:
#     135     # restore the current task
#     136     if curr_task is not None:
#
# File /opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/asyncio/events.py:80, in Handle._run(self)
#      78 def _run(self):
#      79     try:
# ---> 80         self._context.run(self._callback, *self._args)
#      81     except (SystemExit, KeyboardInterrupt):
#      82         raise
#
# File /opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/asyncio/tasks.py:339, in Task.__wakeup(self, future)
#     331     self.__step(exc)
#     332 else:
#     333     # Don't pass the value of `future.result()` explicitly,
#     334     # as `Future.__iter__` and `Future.__await__` don't need it.
#    (...)
#     337     # instead of `__next__()`, which is slower for futures
#     338     # that return non-generator iterators from their `__iter__`.
# --> 339     self.__step()
#     340 self = None
#
# File /opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/asyncio/tasks.py:256, in Task.__step(***failed resolving arguments***)
#     252 try:
#     253     if exc is None:
#     254         # We use the `send` method directly, because coroutines
#     255         # don't have `__iter__` and `__next__` methods.
# --> 256         result = coro.send(None)
#     257     else:
#     258         result = coro.throw(exc)
#
# File /opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/uvicorn/server.py:69, in Server.serve(self, sockets)
#      67 async def serve(self, sockets: list[socket.socket] | None = None) -> None:
#      68     with self.capture_signals():
# ---> 69         await self._serve(sockets)
#
# File /opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/contextlib.py:126, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     124 if typ is None:
#     125     try:
# --> 126         next(self.gen)
#     127     except StopIteration:
#     128         return False
#
# File /opt/homebrew/anaconda3/envs/koBERT/lib/python3.9/site-packages/uvicorn/server.py:328, in Server.capture_signals(self)
#     324 # If we did gracefully shut down due to a signal, try to
#     325 # trigger the expected behaviour now; multiple signals would be
#     326 # done LIFO, see https://stackoverflow.com/questions/48434964
#     327 for captured_signal in reversed(self._captured_signals):
# --> 328     signal.raise_signal(captured_signal)
#
# KeyboardInterrupt:
